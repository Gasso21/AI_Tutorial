# %% [markdown]
# # CIFAR10

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# ## Colorization AutoEncoder
# ### EDA

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import os
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
# Color Image(RGB) -> Gray_Scale Image
# grayscale = 0.299*red + 0.587*green + 0.114*blue
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

# %%
# Data Loading
(x_train, _), (x_test, _) = keras.datasets.cifar10.load_data()
img_rows, img_cols, channels = x_train.shape[1:]
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 14s 0us/step

# %%
# Make saved_imgaes folders
imgs_dir = 'saved_images'
save_dir = os.path.join(os.getcwd(), imgs_dir)
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

# %%
# Show input color images(100)
imgs = x_test[:100]
imgs = imgs.reshape((10, 10, img_rows, img_cols, channels))
imgs = np.vstack([np.hstack(i) for i in imgs])

plt.figure()
plt.axis('off')
plt.title('Test color images (Ground Truth)')
plt.imshow(imgs, interpolation='none')
plt.savefig('%s/test_color.png' %imgs_dir)
plt.show()

# %%
# Change Color to Gray_Scale
x_train_gray = rgb2gray(x_train)
x_test_gray = rgb2gray(x_test)

# %%
# Show input gray images(100)
imgs = x_test_gray[:100]
imgs = imgs.reshape((10, 10, img_rows, img_cols))
imgs = np.vstack([np.hstack(i) for i in imgs])

plt.figure()
plt.axis('off')
plt.title('Test gray imgaes (Input)')
plt.imshow(imgs, interpolation='none', cmap='gray')
plt.savefig('%s/test_gray.png' %save_dir)
plt.show()

# %%
# Regularization
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

x_train_gray = x_train_gray.astype('float32')/255
x_test_gray = x_test_gray.astype('float32')/255

# %%
# Change image shape
x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, channels) # Color Scale
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, channels)

x_train_gray = x_train_gray.reshape(x_train_gray.shape[0], img_rows, img_cols, 1) # Gray Scale
x_test_gray = x_test_gray.reshape(x_test_gray.shape[0], img_rows, img_cols, 1)

# %%
# Network Parameters
input_shape = (img_rows, img_cols, 1)
batch_size = 32
kernel_size = 3
latent_dim = 256

# Encoder & Decoder filters
layer_filters = [64, 128, 256]

# %%
from keras.layers import Conv2D, Flatten, Dense
from keras.layers import Conv2DTranspose, Reshape
from keras import backend as K

# %%
# Encoder Model
def encoder(inputs, layer_filters, latent_dim, kernel_size):
    x = inputs
    for filters in layer_filters:
        x = Conv2D(filters=filters,
                   kernel_size=kernel_size,
                   strides=2,
                   activation='relu',
                   padding='same'
                  )(x)
    shape = K.int_shape(x)
    x = Flatten()(x)
    latent = Dense(latent_dim, name='latent_vector')(x)
    
    return latent, shape

# %%
inputs = keras.Input(shape=input_shape, name='encoder_input')
latent, shape = encoder(inputs, layer_filters, latent_dim, kernel_size)
encoder = keras.Model(inputs, latent, name='encoder')
encoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 32, 32, 1)]       0
#
#  conv2d (Conv2D)             (None, 16, 16, 64)        640
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 128)         73856
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 256)         295168
#
#  flatten (Flatten)           (None, 4096)              0
#
#  latent_vector (Dense)       (None, 256)               1048832
#
# =================================================================
# Total params: 1,418,496
# Trainable params: 1,418,496
# Non-trainable params: 0
# _________________________________________________________________

# %%
def decoder(latent_inputs, shape, layer_filters, kernel_size):
    x = Dense(shape[1]*shape[2]*shape[3])(latent_inputs) # shape: (None, 4, 4, 256)
    x = Reshape((shape[1], shape[2], shape[3]))(x)
    
    for filters in layer_filters[::-1]:
        x = Conv2DTranspose(filters=filters,
                            kernel_size=kernel_size,
                            strides=2,
                            activation='relu',
                            padding='same',
                           )(x)
    outputs = Conv2DTranspose(filters=3,
                              kernel_size=kernel_size,
                              activation='sigmoid',
                              padding='same',
                              name='decoder_ouput'
                             )(x)
    return outputs

# %%
latent_inputs = keras.Input(shape=(latent_dim,), name='decoder_input')
outputs = decoder(latent_inputs, shape, layer_filters, kernel_size)
decoder = keras.Model(latent_inputs, outputs, name='decoder')
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  decoder_input (InputLayer)  [(None, 256)]             0
#
#  dense_1 (Dense)             (None, 4096)              1052672
#
#  reshape_1 (Reshape)         (None, 4, 4, 256)         0
#
#  conv2d_transpose_3 (Conv2DT  (None, 8, 8, 256)        590080
#  ranspose)
#
#  conv2d_transpose_4 (Conv2DT  (None, 16, 16, 128)      295040
#  ranspose)
#
#  conv2d_transpose_5 (Conv2DT  (None, 32, 32, 64)       73792
#  ranspose)
#
#  decoder_ouput (Conv2DTransp  (None, 32, 32, 3)        1731
#  ose)
#
# =================================================================
# Total params: 2,013,315
# Trainable params: 2,013,315
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder = keras.Model(inputs, decoder(encoder(inputs)), name='autoencoder')
autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 32, 32, 1)]       0
#
#  encoder (Functional)        (None, 256)               1418496
#
#  decoder (Functional)        (None, 32, 32, 3)         2013315
#
# =================================================================
# Total params: 3,431,811
# Trainable params: 3,431,811
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Make Directory for saving models
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'colorized_ae_model.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# %%
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5, # 손실값이 5세대 내에 개선되지 않으면 학습속도를 sqrt(0.1) 감소시킴
                               verbose=1,
                               min_lr=0.5e-6
                              )

# Prepare callbacks for model saving and for learning rate adjustment
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True,
                            )

# %%
autoencoder.compile(loss='mse', optimizer='adam')

# %%
callbacks = [lr_reducer, checkpoint]

# %%
autoencoder.fit(x_train_gray, x_train,
                validation_data=(x_test_gray, x_test),
                epochs=30,
                batch_size=batch_size,
                callbacks=callbacks
               )
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0097
# Epoch 1: val_loss improved from inf to 0.00746, saving model to /content/saved_models/colorized_ae_model.001.h5
# 1563/1563 [==============================] - 23s 12ms/step - loss: 0.0097 - val_loss: 0.0075 - lr: 0.0010
# Epoch 2/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 2: val_loss improved from 0.00746 to 0.00729, saving model to /content/saved_models/colorized_ae_model.002.h5
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0068 - val_loss: 0.0073 - lr: 0.0010
# Epoch 3/30
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 3: val_loss did not improve from 0.00729
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0065 - val_loss: 0.0074 - lr: 0.0010
# Epoch 4/30
# 1558/1563 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 4: val_loss improved from 0.00729 to 0.00715, saving model to /content/saved_models/colorized_ae_model.004.h5
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0063 - val_loss: 0.0071 - lr: 0.0010
# Epoch 5/30
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 5: val_loss did not improve from 0.00715
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0062 - val_loss: 0.0073 - lr: 0.0010
# Epoch 6/30
# 1558/1563 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 6: val_loss improved from 0.00715 to 0.00711, saving model to /content/saved_models/colorized_ae_model.006.h5
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0060 - val_loss: 0.0071 - lr: 0.0010
# Epoch 7/30
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 7: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0059 - val_loss: 0.0073 - lr: 0.0010
# Epoch 8/30
# 1558/1563 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 8: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0057 - val_loss: 0.0074 - lr: 0.0010
# Epoch 9/30
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
#
# Epoch 9: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0056 - val_loss: 0.0073 - lr: 0.0010
# Epoch 10/30
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 10: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0048 - val_loss: 0.0072 - lr: 3.1623e-04
# Epoch 11/30
# 1558/1563 [============================>.] - ETA: 0s - loss: 0.0046
# Epoch 11: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0046 - val_loss: 0.0072 - lr: 3.1623e-04
# Epoch 12/30
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0044
# Epoch 12: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0044 - val_loss: 0.0072 - lr: 3.1623e-04
# Epoch 13/30
# 1558/1563 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 13: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0043 - val_loss: 0.0074 - lr: 3.1623e-04
# Epoch 14/30
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.0042
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
#
# Epoch 14: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0042 - val_loss: 0.0075 - lr: 3.1623e-04
# Epoch 15/30
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 15: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0038 - val_loss: 0.0074 - lr: 1.0000e-04
# Epoch 16/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 16: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0038 - val_loss: 0.0075 - lr: 1.0000e-04
# Epoch 17/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 17: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0037 - val_loss: 0.0074 - lr: 1.0000e-04
# Epoch 18/30
# 1558/1563 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 18: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0037 - val_loss: 0.0075 - lr: 1.0000e-04
# Epoch 19/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 19: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
#
# Epoch 19: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0036 - val_loss: 0.0076 - lr: 1.0000e-04
# Epoch 20/30
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 20: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0035 - val_loss: 0.0076 - lr: 3.1623e-05
# Epoch 21/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 21: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0035 - val_loss: 0.0076 - lr: 3.1623e-05
# Epoch 22/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 22: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0035 - val_loss: 0.0076 - lr: 3.1623e-05
# Epoch 23/30
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 23: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0035 - val_loss: 0.0076 - lr: 3.1623e-05
# Epoch 24/30
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.0000000409520217e-05.
#
# Epoch 24: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0035 - val_loss: 0.0076 - lr: 3.1623e-05
# Epoch 25/30
# 1558/1563 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 25: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0034 - val_loss: 0.0077 - lr: 1.0000e-05
# Epoch 26/30
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 26: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0034 - val_loss: 0.0077 - lr: 1.0000e-05
# Epoch 27/30
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 27: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0034 - val_loss: 0.0077 - lr: 1.0000e-05
# Epoch 28/30
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 28: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0034 - val_loss: 0.0077 - lr: 1.0000e-05
# Epoch 29/30
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.1622778678900043e-06.
#
# Epoch 29: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0034 - val_loss: 0.0077 - lr: 1.0000e-05
# Epoch 30/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 30: val_loss did not improve from 0.00711
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0034 - val_loss: 0.0077 - lr: 3.1623e-06

# %%
x_decoded = autoencoder.predict(x_test_gray)
# Out:
# 313/313 [==============================] - 1s 4ms/step

# %%
imgs = x_decoded[:100]
imgs = imgs.reshape((10, 10, img_rows, img_cols, channels))
imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure()
plt.axis('off')
plt.title('Colorized test images (Predicted)')
plt.imshow(imgs, interpolation='none')
plt.savefig('%s/colorized.png' %imgs_dir)
plt.show()
