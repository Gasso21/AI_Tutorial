# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# # MNIST

# %% [markdown]
# ## Load Data

# %%
import tensorflow as tf
from tensorflow import keras
from keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

unique, counts = np.unique(y_train, return_counts=True)
print(f"Train Labels: {dict(zip(unique, counts))}")

unique, counts = np.unique(y_test, return_counts=True)
print(f"Test Labels: {dict(zip(unique, counts))}")
# Out:
# Train Labels: {0: 5923, 1: 6742, 2: 5958, 3: 6131, 4: 5842, 5: 5421, 6: 5918, 7: 6265, 8: 5851, 9: 5949}
# Test Labels: {0: 980, 1: 1135, 2: 1032, 3: 1010, 4: 982, 5: 892, 6: 958, 7: 1028, 8: 974, 9: 1009}

# %%
indexes = np.random.randint(0, x_train.shape[0], size=9)
images = x_train[indexes]
labels = y_train[indexes]

# %%
plt.figure(figsize=(5, 5))
for i in range(len(indexes)):
    plt.subplot(3, 3, i+1)
    plt.imshow(images[i], cmap='gray')
    plt.axis('off')
    plt.title(labels[i])
plt.show()

# %% [markdown]
# ## Preprocessing

# %%
num_labels = len(unique)

y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

x_train = np.reshape(x_train, [-1, x_train.shape[1], x_train.shape[2], 1])
x_test = np.reshape(x_test, [-1, x_test.shape[1], x_test.shape[2], 1])
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

input_shape = x_train.shape[1:]

# %% [markdown]
# # LeNet-5

# %% [markdown]
# ### Input Shape: 28x28x1(MNIST)
# **Convolution Layers**
#
# 1. ConV_1 (5x5, s=1, activation='tanh', filters=  6, padding='same')
# 2. Pooling_2 (f=2, s=2, padding='valid')
# 3. ConV_3 (5x5, s=1, activation='tanh', filters= 16, padding='valid')
# 4. Pooling_4 (f=2, s=2, padding='valid')
# 5. ConV_5 (5x5, s=1, activation='tanh', filters=120, padding='valid')
#
# **Fully Connected Layers**
#
# 6. Dense(units=84, activation='tanh')
#
# **Outputs**
#
# 7. Dense(units=10, activation='softmax')

# %%
from LeNet import build_lenet_5, lr_schedule

# %%
model = build_lenet_5(input_shape=input_shape)
model.summary()
# Out:
# Metal device set to: Apple M2
# Model: "LeNet_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 6)         156
#
#  average_pooling2d (AverageP  (None, 14, 14, 6)        0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 16)        2416
#
#  average_pooling2d_1 (Averag  (None, 5, 5, 16)         0
#  ePooling2D)
#
#  conv2d_2 (Conv2D)           (None, 1, 1, 120)         48120
#
#  flatten (Flatten)           (None, 120)               0
#
#  dense (Dense)               (None, 84)                10164
#
#  dense_1 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# 2023-03-17 20:54:03.848946: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-17 20:54:03.849039: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
import os

save_dir = os.path.join(os.getcwd(), 'LeNet')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

# %%
filepath1 = os.path.join(save_dir, 'LeNet5.png')

keras.utils.plot_model(model=model,
                       to_file=filepath1,
                       show_shapes=True
                      )

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler

model_name = 'mnist_lenet_v5.{epoch:03d}.h5'
filepath2 = os.path.join(save_dir, model_name)

lr_scheduler = LearningRateScheduler(lr_schedule)
checkpoints = ModelCheckpoint(filepath=filepath2,
                              monitor='val_accuracy',
                              verbose=1,
                              save_best_only=True
                             )
callbacks = [checkpoints, lr_scheduler]

model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy']
             )

# %%
hist = model.fit(x_train, y_train, 
                 batch_size=32, 
                 epochs=20,
                 validation_data=(x_test, y_test),
                 callbacks=callbacks,
                 verbose=2,
                 shuffle=True
                )
# Out:
# Epoch 1/20
# 2023-03-17 20:54:04.679901: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-17 20:54:04.826522: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-03-17 20:54:19.360757: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_accuracy improved from -inf to 0.64310, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/LeNet/mnist_lenet_v5.001.h5
# 1875/1875 - 16s - loss: 2.1945 - accuracy: 0.4328 - val_loss: 2.0447 - val_accuracy: 0.6431 - lr: 5.0000e-04 - 16s/epoch - 9ms/step
# Epoch 2/20
#
# Epoch 2: val_accuracy improved from 0.64310 to 0.72850, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/LeNet/mnist_lenet_v5.002.h5
# 1875/1875 - 16s - loss: 1.7402 - accuracy: 0.6691 - val_loss: 1.3744 - val_accuracy: 0.7285 - lr: 5.0000e-04 - 16s/epoch - 8ms/step
# Epoch 3/20
#
# Epoch 3: val_accuracy improved from 0.72850 to 0.80060, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/LeNet/mnist_lenet_v5.003.h5
# 1875/1875 - 16s - loss: 1.1267 - accuracy: 0.7525 - val_loss: 0.9160 - val_accuracy: 0.8006 - lr: 5.0000e-04 - 16s/epoch - 8ms/step
# Epoch 4/20
#
# Epoch 4: val_accuracy improved from 0.80060 to 0.82130, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/LeNet/mnist_lenet_v5.004.h5
# 1875/1875 - 16s - loss: 0.8788 - accuracy: 0.7996 - val_loss: 0.8158 - val_accuracy: 0.8213 - lr: 2.0000e-04 - 16s/epoch - 8ms/step
# Epoch 5/20
#
# Epoch 5: val_accuracy improved from 0.82130 to 0.83480, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/LeNet/mnist_lenet_v5.005.h5
# 1875/1875 - 16s - loss: 0.7923 - accuracy: 0.8187 - val_loss: 0.7406 - val_accuracy: 0.8348 - lr: 2.0000e-04 - 16s/epoch - 8ms/step
# Epoch 6/20
#
# Epoch 6: val_accuracy improved from 0.83480 to 0.84580, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/LeNet/mnist_lenet_v5.006.h5
# 1875/1875 - 16s - loss: 0.7261 - accuracy: 0.8318 - val_loss: 0.6822 - val_accuracy: 0.8458 - lr: 2.0000e-04 - 16s/epoch - 9ms/step
# Epoch 7/20
#
# Epoch 7: val_accuracy improved from 0.84580 to 0.84880, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/LeNet/mnist_lenet_v5.007.h5
# 1875/1875 - 16s - loss: 0.6917 - accuracy: 0.8392 - val_loss: 0.6696 - val_accuracy: 0.8488 - lr: 5.0000e-05 - 16s/epoch - 9ms/step
# Epoch 8/20
#
# Epoch 8: val_accuracy improved from 0.84880 to 0.85110, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/LeNet/mnist_lenet_v5.008.h5
# 1875/1875 - 16s - loss: 0.6794 - accuracy: 0.8417 - val_loss: 0.6577 - val_accuracy: 0.8511 - lr: 5.0000e-05 - 16s/epoch - 9ms/step
# Epoch 9/20
#
# Epoch 9: val_accuracy improved from 0.85110 to 0.85330, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/LeNet/mnist_lenet_v5.009.h5
# 1875/1875 - 16s - loss: 0.6678 - accuracy: 0.8436 - val_loss: 0.6465 - val_accuracy: 0.8533 - lr: 5.0000e-05 - 16s/epoch - 9ms/step
# Epoch 10/20
#
# Epoch 10: val_accuracy improved from 0.85330 to 0.85520, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/LeNet/mnist_lenet_v5.010.h5
# 1875/1875 - 16s - loss: 0.6568 - accuracy: 0.8453 - val_loss: 0.6358 - val_accuracy: 0.8552 - lr: 5.0000e-05 - 16s/epoch - 8ms/step
# Epoch 11/20
#
# Epoch 11: val_accuracy improved from 0.85520 to 0.85630, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/LeNet/mnist_lenet_v5.011.h5
# 1875/1875 - 16s - loss: 0.6504 - accuracy: 0.8466 - val_loss: 0.6337 - val_accuracy: 0.8563 - lr: 1.0000e-05 - 16s/epoch - 8ms/step
# Epoch 12/20
#
# Epoch 12: val_accuracy improved from 0.85630 to 0.85650, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/LeNet/mnist_lenet_v5.012.h5
# 1875/1875 - 16s - loss: 0.6483 - accuracy: 0.8471 - val_loss: 0.6317 - val_accuracy: 0.8565 - lr: 1.0000e-05 - 16s/epoch - 8ms/step
# Epoch 13/20
#
# Epoch 13: val_accuracy did not improve from 0.85650
# 1875/1875 - 16s - loss: 0.6463 - accuracy: 0.8474 - val_loss: 0.6296 - val_accuracy: 0.8565 - lr: 1.0000e-05 - 16s/epoch - 8ms/step
# Epoch 14/20
#
# Epoch 14: val_accuracy improved from 0.85650 to 0.85690, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/LeNet/mnist_lenet_v5.014.h5
# 1875/1875 - 16s - loss: 0.6443 - accuracy: 0.8477 - val_loss: 0.6276 - val_accuracy: 0.8569 - lr: 1.0000e-05 - 16s/epoch - 8ms/step
# Epoch 15/20
#
# Epoch 15: val_accuracy improved from 0.85690 to 0.85730, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/LeNet/mnist_lenet_v5.015.h5
# 1875/1875 - 16s - loss: 0.6423 - accuracy: 0.8482 - val_loss: 0.6256 - val_accuracy: 0.8573 - lr: 1.0000e-05 - 16s/epoch - 8ms/step
# Epoch 16/20
#
# Epoch 16: val_accuracy improved from 0.85730 to 0.85790, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/LeNet/mnist_lenet_v5.016.h5
# 1875/1875 - 16s - loss: 0.6403 - accuracy: 0.8486 - val_loss: 0.6237 - val_accuracy: 0.8579 - lr: 1.0000e-05 - 16s/epoch - 8ms/step
# Epoch 17/20
#
# Epoch 17: val_accuracy improved from 0.85790 to 0.85800, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/LeNet/mnist_lenet_v5.017.h5
# 1875/1875 - 16s - loss: 0.6383 - accuracy: 0.8490 - val_loss: 0.6217 - val_accuracy: 0.8580 - lr: 1.0000e-05 - 16s/epoch - 8ms/step
# Epoch 18/20
#
# Epoch 18: val_accuracy improved from 0.85800 to 0.85830, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/LeNet/mnist_lenet_v5.018.h5
# 1875/1875 - 16s - loss: 0.6364 - accuracy: 0.8494 - val_loss: 0.6198 - val_accuracy: 0.8583 - lr: 1.0000e-05 - 16s/epoch - 8ms/step
# Epoch 19/20
#
# Epoch 19: val_accuracy improved from 0.85830 to 0.85870, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/LeNet/mnist_lenet_v5.019.h5
# 1875/1875 - 16s - loss: 0.6344 - accuracy: 0.8494 - val_loss: 0.6179 - val_accuracy: 0.8587 - lr: 1.0000e-05 - 16s/epoch - 8ms/step
# Epoch 20/20
#
# Epoch 20: val_accuracy improved from 0.85870 to 0.85900, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/LeNet/mnist_lenet_v5.020.h5
# 1875/1875 - 16s - loss: 0.6325 - accuracy: 0.8498 - val_loss: 0.6160 - val_accuracy: 0.8590 - lr: 1.0000e-05 - 16s/epoch - 8ms/step

# %%
loss, acc = model.evaluate(x_test, y_test, batch_size=32)
print(f"Test accuracy: {(100*acc):>.1f}%")
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6160 - accuracy: 0.8590
# Test accuracy: 85.9%

# %%
plt.plot(hist.history['loss'], 'b-', label='loss')
plt.plot(hist.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.xticks(range(20))
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(hist.history['accuracy'], 'b-', label='acc')
plt.plot(hist.history['val_accuracy'], 'r--', label='val_acc')
plt.xlabel('Epoch')
plt.xticks(range(20))
plt.grid()
plt.legend()
plt.show()

# %%
# %load_ext tensorboard

# %%
new_model = build_lenet_5(input_shape=input_shape)
new_model.compile(loss='categorical_crossentropy',
                  optimizer='sgd',
                  metrics=['accuracy']
                 )

# %%
new_model.evaluate(x_test,y_test)
# Out:
#  18/313 [>.............................] - ETA: 1s - loss: 2.2956 - accuracy: 0.1024
# 2023-03-17 20:59:24.656370: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 2s 6ms/step - loss: 2.2954 - accuracy: 0.1166
# [2.2954368591308594, 0.11660000681877136]

# %%
log_dir = 'log'
filepath3 = os.path.join(save_dir, log_dir)

tensorboard_cb = keras.callbacks.TensorBoard(filepath3, histogram_freq=1)

# %%
new_model.fit(x_train, y_train,
              epochs=20,
              batch_size=32,
              validation_data=(x_test, y_test),
              callbacks=[tensorboard_cb]
             )
# Out:
# Epoch 1/20
#    6/1875 [..............................] - ETA: 20s - loss: 2.2921 - accuracy: 0.0677
# 2023-03-17 20:59:26.782383: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.6319 - accuracy: 0.8379 - val_loss: 0.3000 - val_accuracy: 0.9153
# Epoch 2/20
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.2684 - accuracy: 0.9210 - val_loss: 0.2159 - val_accuracy: 0.9365
# Epoch 3/20
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.2033 - accuracy: 0.9399 - val_loss: 0.1701 - val_accuracy: 0.9501
# Epoch 4/20
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.1606 - accuracy: 0.9520 - val_loss: 0.1334 - val_accuracy: 0.9589
# Epoch 5/20
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.1303 - accuracy: 0.9612 - val_loss: 0.1108 - val_accuracy: 0.9675
# Epoch 6/20
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.1096 - accuracy: 0.9671 - val_loss: 0.0931 - val_accuracy: 0.9726
# Epoch 7/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0936 - accuracy: 0.9722 - val_loss: 0.0842 - val_accuracy: 0.9755
# Epoch 8/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0827 - accuracy: 0.9755 - val_loss: 0.0740 - val_accuracy: 0.9768
# Epoch 9/20
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0736 - accuracy: 0.9778 - val_loss: 0.0679 - val_accuracy: 0.9785
# Epoch 10/20
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0667 - accuracy: 0.9802 - val_loss: 0.0604 - val_accuracy: 0.9809
# Epoch 11/20
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0613 - accuracy: 0.9817 - val_loss: 0.0572 - val_accuracy: 0.9819
# Epoch 12/20
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0565 - accuracy: 0.9834 - val_loss: 0.0517 - val_accuracy: 0.9829
# Epoch 13/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0528 - accuracy: 0.9840 - val_loss: 0.0483 - val_accuracy: 0.9843
# Epoch 14/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0493 - accuracy: 0.9857 - val_loss: 0.0461 - val_accuracy: 0.9857
# Epoch 15/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0467 - accuracy: 0.9860 - val_loss: 0.0453 - val_accuracy: 0.9852
# Epoch 16/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0439 - accuracy: 0.9870 - val_loss: 0.0449 - val_accuracy: 0.9849
# Epoch 17/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0417 - accuracy: 0.9876 - val_loss: 0.0417 - val_accuracy: 0.9868
# Epoch 18/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0396 - accuracy: 0.9885 - val_loss: 0.0387 - val_accuracy: 0.9873
# Epoch 19/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0380 - accuracy: 0.9888 - val_loss: 0.0391 - val_accuracy: 0.9874
# Epoch 20/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0361 - accuracy: 0.9892 - val_loss: 0.0389 - val_accuracy: 0.9876

# %%
# %tensorboard --logdir $filepath3
# Out:
#       <iframe id="tensorboard-frame-4c63af644cecfc68" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4c63af644cecfc68");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
"""
.save_weights(path)
.save(path)
keras.models.load_model(path)
"""
# Out:
# '\n.save_weights(path)\n.save(path)\nkeras.models.load_model(path)\n'

# %% [markdown]
# # Cifar10
# ## LoadData

# %%
from keras.datasets import cifar10
import numpy as np

# %%
(x_train, y_train),(x_test, y_test) = cifar10.load_data()

unique, counts = np.unique(y_train, return_counts=True)
print(f"Train Labels: {dict(zip(unique, counts))}")

unique, counts = np.unique(y_test, return_counts=True)
print(f"Test Labels: {dict(zip(unique, counts))}")
# Out:
# Train Labels: {0: 5000, 1: 5000, 2: 5000, 3: 5000, 4: 5000, 5: 5000, 6: 5000, 7: 5000, 8: 5000, 9: 5000}
# Test Labels: {0: 1000, 1: 1000, 2: 1000, 3: 1000, 4: 1000, 5: 1000, 6: 1000, 7: 1000, 8: 1000, 9: 1000}

# %% [markdown]
# # ImageNet
# ## LoadData

# %%
from keras.datasets import

# %% [markdown]
# # AlexNet

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? n
# Nothing done.

# %% [markdown]
# ### Input Shape: 227x227x3(ImageNet)
# **Convolution Layers**
#
# 1. ConV (11x11, s=4, activation='relu', filters=96, padding='valid')
# 2. MaxPool (f=3, s=2)
# 3. BatchNorm
# 4. ConV (5x5, s=1, activation='relu', filters=256, padding='same', regularizer='l2')
# 5. MaxPool (f=3, s=2, padding='valid')
# 6. BatchNorm
# 7. ConV (3x3, s=1, activation='relu', filters=384, pading='same', regularizer='l2')
# 8. BatchNorm
# 9. ConV (3x3, s=1, activation='relu', filters=384, pading='same', regularizer='l2')
# 10. BatchNorm
# 11. ConV (3x3, s=1, activation='relu', filters=256, pading='same', regularizer='l2')
# 12. BatchNorm
# 13. MaxPool (f=3, s=2, padding='valid')
# 14. Flatten
#
# **Fully Connected Layers**
#
# 15. Dense(units=4096, activation='relu')
# 16. Dropout(0.5)
# 17. Dense(units=4096, activation='relu')
# 18. Dropout(0.5)
#
# **Outputs**
#
# 19. Dense(units=1000, activation='softmax')

# %%
from AlexNet import build_alexnet

model = build_alexnet((227,227,3))
model.summary()
# Out:
# Model: "AlexNet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 227, 227, 3)]     0
#
#  conv2d_6 (Conv2D)           (None, 55, 55, 96)        34944
#
#  max_pooling2d (MaxPooling2D  (None, 27, 27, 96)       0
#  )
#
#  batch_normalization (BatchN  (None, 27, 27, 96)       384
#  ormalization)
#
#  conv2d_7 (Conv2D)           (None, 27, 27, 256)       614656
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 256)      0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 13, 13, 256)      1024
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 13, 13, 384)       885120
#
#  batch_normalization_2 (Batc  (None, 13, 13, 384)      1536
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 13, 13, 384)       1327488
#
#  batch_normalization_3 (Batc  (None, 13, 13, 384)      1536
#  hNormalization)
#
#  conv2d_10 (Conv2D)          (None, 13, 13, 256)       884992
#
#  batch_normalization_4 (Batc  (None, 13, 13, 256)      1024
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  flatten_2 (Flatten)         (None, 9216)              0
#
#  dense_4 (Dense)             (None, 4096)              37752832
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_5 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_6 (Dense)             (None, 1000)              4097000
#
# =================================================================
# Total params: 62,383,848
# Trainable params: 62,381,096
# Non-trainable params: 2,752
# _________________________________________________________________

# %%
import os

save_dir = os.path.join(os.getcwd(), 'AlexNet')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

filepath1 = os.path.join(save_dir, 'AlexNet.png')

keras.utils.plot_model(model=model,
                       to_file=filepath1,
                       show_shapes=True
                      )

# %% [markdown]
# # VGG16

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# ### Input Shape: 28x28x1(MNIST)
# **Convolution Layers**
#
# - ConV (k=3, s=1, f=64, a='relu', p='same')
# - ConV (k=3, s=1, f=64, a='relu', p='same')
# - MaxPool (p=2, s=2)
#
# - ConV (k=3, s=1, f=128, a='relu', p='same')
# - ConV (k=3, s=1, f=128, a='relu', p='same')
# - MaxPool (p=2, s=2)
#
# - ConV (k=3, s=1, f=256, a='relu', p='same')
# - ConV (k=3, s=1, f=256, a='relu', p='same')
# - ConV (k=3, s=1, f=256, a='relu', p='same')
# - MaxPool (p=2, s=2)
#
# - ConV (k=3, s=1, f=512, a='relu', p='same')
# - ConV (k=3, s=1, f=512, a='relu', p='same')
# - ConV (k=3, s=1, f=512, a='relu', p='same')
# - MaxPool (p=2, s=2)
#
# - ConV (k=3, s=1, f=512, a='relu', p='same')
# - ConV (k=3, s=1, f=512, a='relu', p='same')
# - ConV (k=3, s=1, f=512, a='relu', p='same')
# - MaxPool (p=2, s=2)
#
# **Fully Connected Layers**
#
# - Flatten
# - Dense(units=4096, activation='relu')
# - Dropout(0.5)
# - Dense(units=4096, activation='relu')
# - Dropout(0.5)
#
# **Outputs**
#
# 10. Dense(units=1000, activation='softmax')

# %%
from VGG16 import build_vgg16

model = build_vgg16((227, 227, 3))
model.summary()
# Out:
# Model: "VGG16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 227, 227, 3)]     0
#
#  conv2d_24 (Conv2D)          (None, 227, 227, 64)      1792
#
#  conv2d_25 (Conv2D)          (None, 227, 227, 64)      36928
#
#  max_pooling2d_8 (MaxPooling  (None, 113, 113, 64)     0
#  2D)
#
#  conv2d_26 (Conv2D)          (None, 113, 113, 128)     73856
#
#  conv2d_27 (Conv2D)          (None, 113, 113, 128)     147584
#
#  max_pooling2d_9 (MaxPooling  (None, 56, 56, 128)      0
#  2D)
#
#  conv2d_28 (Conv2D)          (None, 56, 56, 256)       295168
#
#  conv2d_29 (Conv2D)          (None, 56, 56, 256)       590080
#
#  conv2d_30 (Conv2D)          (None, 56, 56, 256)       590080
#
#  max_pooling2d_10 (MaxPoolin  (None, 28, 28, 256)      0
#  g2D)
#
#  conv2d_31 (Conv2D)          (None, 28, 28, 512)       1180160
#
#  conv2d_32 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  conv2d_33 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  max_pooling2d_11 (MaxPoolin  (None, 14, 14, 512)      0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_35 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_36 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_12 (MaxPoolin  (None, 7, 7, 512)        0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 25088)             0
#
#  dense_10 (Dense)            (None, 4096)              102764544
#
#  dropout_4 (Dropout)         (None, 4096)              0
#
#  dense_11 (Dense)            (None, 4096)              16781312
#
#  dropout_5 (Dropout)         (None, 4096)              0
#
#  dense_12 (Dense)            (None, 1000)              4097000
#
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
import os

save_dir = os.path.join(os.getcwd(), 'VGG16')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
filepath1 = os.path.join(save_dir, 'VGG16.png')

keras.utils.plot_model(model=model,
                       to_file=filepath1,
                       show_shapes=True
                      )

# %% [markdown]
# # MNIST
# ## Load Data

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow import keras
import tensorflow as tf
from keras.datasets import cifar10, mnist
import numpy as np

(x_train, y_train),(x_test, y_test) = mnist.load_data()

unique, counts = np.unique(y_train, return_counts=True)
print(f"Train Labels: {dict(zip(unique, counts))}")

unique, counts = np.unique(y_test, return_counts=True)
print(f"Test Labels: {dict(zip(unique, counts))}")

print(x_train.shape)
# Out:
# Train Labels: {0: 5923, 1: 6742, 2: 5958, 3: 6131, 4: 5842, 5: 5421, 6: 5918, 7: 6265, 8: 5851, 9: 5949}
# Test Labels: {0: 980, 1: 1135, 2: 1032, 3: 1010, 4: 982, 5: 892, 6: 958, 7: 1028, 8: 974, 9: 1009}
# (60000, 28, 28)

# %%
x_train = tf.pad(x_train, [[0,0], [2,2], [2,2]])/255
x_train = tf.expand_dims(x_train, axis=3, name=None)
x_train = tf.repeat(x_train, 3, axis=3)

x_test = tf.pad(x_test, [[0,0], [2,2], [2,2]])/255
x_test = tf.expand_dims(x_test, axis=3, name=None)
x_test = tf.repeat(x_test, 3, axis=3)

y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)


x_val = x_train[-2000:, :, :, :]
y_val = y_train[-2000:]
x_train = x_train[:-2000, :, :, :]
y_train = y_train[:-2000]

print(x_train.shape)
print(x_val.shape)
print(y_train.shape)
# Out:
# (58000, 32, 32, 3)
# (2000, 32, 32, 3)
# (58000, 10)

# %% [markdown]
# # GoogleNet
# ## Inception Module
# ### bottleneck layer

# %%
import os
os.chdir('/content/drive/MyDrive/Colab_Notebooks')
os.getcwd()
# Out:
# '/content/drive/MyDrive/Colab_Notebooks'

# %%
from GoogLeNet import inception_module, build_GoogLeNet

# %%
input_shape = (32, 32, 3)
model = build_GoogLeNet(input_shape=input_shape)
model.summary()
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Model: "GoogLeNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  resizing (Resizing)            (None, 224, 224, 3)  0           ['input_1[0][0]']
#
#  conv_1_7x7/2 (Conv2D)          (None, 112, 112, 64  9472        ['resizing[0][0]']
#                                 )
#
#  max_pool_1_3x3/2 (MaxPooling2D  (None, 56, 56, 64)  0           ['conv_1_7x7/2[0][0]']
#  )
#
#  batch_normalization (BatchNorm  (None, 56, 56, 64)  256         ['max_pool_1_3x3/2[0][0]']
#  alization)
#
#  conv2d (Conv2D)                (None, 56, 56, 64)   4160        ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 192)  110784      ['conv2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 192)  768        ['conv2d_1[0][0]']
#  rmalization)
#
#  max_pooling2d (MaxPooling2D)   (None, 28, 28, 192)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 96)   18528       ['max_pooling2d[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 16)   3088        ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 192)  0          ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 64)   12352       ['max_pooling2d[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 128)  110720      ['conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 32)   12832       ['conv2d_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 32)   6176        ['max_pooling2d_1[0][0]']
#
#  inception_3a (Concatenate)     (None, 28, 28, 256)  0           ['conv2d_2[0][0]',
#                                                                   'conv2d_4[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 128)  32896       ['inception_3a[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 32)   8224        ['inception_3a[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 256)  0          ['inception_3a[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 128)  32896       ['inception_3a[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 192)  221376      ['conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 96)   76896       ['conv2d_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 64)   16448       ['max_pooling2d_2[0][0]']
#
#  inception_3b (Concatenate)     (None, 28, 28, 480)  0           ['conv2d_8[0][0]',
#                                                                   'conv2d_10[0][0]',
#                                                                   'conv2d_12[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 480)  0          ['inception_3b[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 14, 14, 96)   46176       ['max_pooling2d_3[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 16)   7696        ['max_pooling2d_3[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 480)  0          ['max_pooling2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 14, 14, 192)  92352       ['max_pooling2d_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 208)  179920      ['conv2d_15[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 14, 14, 48)   19248       ['conv2d_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 14, 14, 64)   30784       ['max_pooling2d_4[0][0]']
#
#  inception_4a (Concatenate)     (None, 14, 14, 512)  0           ['conv2d_14[0][0]',
#                                                                   'conv2d_16[0][0]',
#                                                                   'conv2d_18[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 112)  57456       ['inception_4a[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 24)   12312       ['inception_4a[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 14, 14, 512)  0          ['inception_4a[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 160)  82080       ['inception_4a[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 224)  226016      ['conv2d_21[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 64)   38464       ['conv2d_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_5[0][0]']
#
#  inception_4b (Concatenate)     (None, 14, 14, 512)  0           ['conv2d_20[0][0]',
#                                                                   'conv2d_22[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 128)  65664       ['inception_4b[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 14, 14, 24)   12312       ['inception_4b[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 512)  0          ['inception_4b[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 128)  65664       ['inception_4b[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 256)  295168      ['conv2d_27[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 14, 14, 64)   38464       ['conv2d_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_6[0][0]']
#
#  inception_4c (Concatenate)     (None, 14, 14, 512)  0           ['conv2d_26[0][0]',
#                                                                   'conv2d_28[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 14, 14, 144)  73872       ['inception_4c[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 14, 14, 32)   16416       ['inception_4c[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 512)  0          ['inception_4c[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 14, 14, 112)  57456       ['inception_4c[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 14, 14, 288)  373536      ['conv2d_33[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 14, 14, 64)   51264       ['conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_7[0][0]']
#
#  inception_4d (Concatenate)     (None, 14, 14, 528)  0           ['conv2d_32[0][0]',
#                                                                   'conv2d_34[0][0]',
#                                                                   'conv2d_36[0][0]',
#                                                                   'conv2d_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 14, 14, 160)  84640       ['inception_4d[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 14, 14, 32)   16928       ['inception_4d[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 14, 14, 528)  0          ['inception_4d[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 14, 14, 256)  135424      ['inception_4d[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 14, 14, 320)  461120      ['conv2d_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 128)  102528      ['conv2d_41[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 128)  67712       ['max_pooling2d_8[0][0]']
#
#  inception_4e (Concatenate)     (None, 14, 14, 832)  0           ['conv2d_38[0][0]',
#                                                                   'conv2d_40[0][0]',
#                                                                   'conv2d_42[0][0]',
#                                                                   'conv2d_43[0][0]']
#
#  max_pool_4_3x3/2 (MaxPooling2D  (None, 7, 7, 832)   0           ['inception_4e[0][0]']
#  )
#
#  conv2d_45 (Conv2D)             (None, 7, 7, 160)    133280      ['max_pool_4_3x3/2[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 7, 7, 32)     26656       ['max_pool_4_3x3/2[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 7, 7, 832)   0           ['max_pool_4_3x3/2[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 7, 7, 256)    213248      ['max_pool_4_3x3/2[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 7, 7, 320)    461120      ['conv2d_45[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 7, 7, 128)    102528      ['conv2d_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 7, 7, 128)    106624      ['max_pooling2d_9[0][0]']
#
#  inception_5a (Concatenate)     (None, 7, 7, 832)    0           ['conv2d_44[0][0]',
#                                                                   'conv2d_46[0][0]',
#                                                                   'conv2d_48[0][0]',
#                                                                   'conv2d_49[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 7, 7, 192)    159936      ['inception_5a[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 7, 7, 48)     39984       ['inception_5a[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 7, 7, 832)   0           ['inception_5a[0][0]']
#  )
#
#  conv2d_50 (Conv2D)             (None, 7, 7, 384)    319872      ['inception_5a[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 7, 7, 384)    663936      ['conv2d_51[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 7, 7, 128)    153728      ['conv2d_53[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 7, 7, 128)    106624      ['max_pooling2d_10[0][0]']
#
#  inception_5b (Concatenate)     (None, 7, 7, 1024)   0           ['conv2d_50[0][0]',
#                                                                   'conv2d_52[0][0]',
#                                                                   'conv2d_54[0][0]',
#                                                                   'conv2d_55[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 1024)  0           ['inception_5b[0][0]']
#  ing2D)
#
#  dropout (Dropout)              (None, 1, 1, 1024)   0           ['average_pooling2d[0][0]']
#
#  flatten (Flatten)              (None, 1024)         0           ['dropout[0][0]']
#
#  output (Dense)                 (None, 10)           10250       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 5,984,826
# Trainable params: 5,984,314
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
import math
from keras.callbacks import LearningRateScheduler

epochs = 5 #25
initial_lrate = 0.01

def decay(epoch, steps=100):
    initial_lrate = 0.01
    # decay 4% every 8epoch
    drop = 0.96
    epochs_drop = 8
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

lr_schedule = LearningRateScheduler(decay, verbose=1)
sgd = keras.optimizers.SGD(learning_rate=initial_lrate, momentum=0.9, nesterov=False)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy']
             )

hist = model.fit(x_train, y_train, batch_size=256, epochs=epochs,
                 validation_data=(x_val, y_val), callbacks=[lr_schedule], verbose=2,
                 shuffle=True
                )
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.01.
# Epoch 1/5
# 227/227 - 233s - loss: 0.8783 - accuracy: 0.6921 - val_loss: 0.6555 - val_accuracy: 0.8475 - lr: 0.0100 - 233s/epoch - 1s/step
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.01.
# Epoch 2/5
# 227/227 - 194s - loss: 0.1138 - accuracy: 0.9656 - val_loss: 0.0649 - val_accuracy: 0.9835 - lr: 0.0100 - 194s/epoch - 853ms/step
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.01.
# Epoch 3/5
# 227/227 - 193s - loss: 0.0734 - accuracy: 0.9772 - val_loss: 0.0388 - val_accuracy: 0.9880 - lr: 0.0100 - 193s/epoch - 851ms/step
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.01.
# Epoch 4/5
# 227/227 - 194s - loss: 0.0585 - accuracy: 0.9818 - val_loss: 0.0284 - val_accuracy: 0.9925 - lr: 0.0100 - 194s/epoch - 853ms/step
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.01.
# Epoch 5/5
# 227/227 - 194s - loss: 0.0431 - accuracy: 0.9867 - val_loss: 0.0233 - val_accuracy: 0.9945 - lr: 0.0100 - 194s/epoch - 854ms/step

# %% [markdown]
# # ResNet

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Conv2D, BatchNormalization, Activation, Add, MaxPooling2D, AveragePooling2D, Flatten, Dense

# %%
def bottleneck_residual_block(X, kernel_size, filters, reduce=False, s=2):
    F1, F2, F3 = filters
    X_shortcut = X
    
    if reduce:
        X_shortcut = Conv2D(filters=F3, kernel_size=1, strides=s)(X_shortcut)
        X_shortcut = BatchNormalization(axis=3)(X_shortcut)
        
        X = Conv2D(filters=F1, kernel_size=1, strides=s, padding='valid')(X)
        X = BatchNormalization(axis=3)(X)
        X = Activation('relu')(X)
        
    else:
        # 1-layers Conv
        X = Conv2D(filters=F1, kernel_size=1, strides=1, padding='same')(X)
        X = BatchNormalization(axis=3)(X)
        X = Activation('relu')(X)
    
    # 2-layers Conv
    X = Conv2D(filters=F2, kernel_size=kernel_size, strides=1, padding='same')(X)
    X = BatchNormalization(axis=3)(X)
    X = Activation('relu')(X)
    
    # 3-layers Conv
    X = Conv2D(filters=F3, kernel_size=1, strides=1, padding='valid')(X)
    X = BatchNormalization(axis=3)(X)
    
    # Last Stage
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %%
def ResNet50(input_shape, classes):
    X_input = keras.Input(shape=input_shape)
    
    # Step 1
    X = Conv2D(filters=64, kernel_size=7, strides=2, name='conv1')(X_input)
    X = BatchNormalization(axis=3, name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D(pool_size=3, strides=2)(X)
    
    # Step 2
    X = bottleneck_residual_block(X, 3, [64, 64, 256], reduce=True, s=1)
    X = bottleneck_residual_block(X, 3, [64, 64, 256])
    X = bottleneck_residual_block(X, 3, [64, 64, 256])
    
    # Step 3
    X = bottleneck_residual_block(X, 3, [128, 128, 512], reduce=True, s=2)
    X = bottleneck_residual_block(X, 3, [128, 128, 512])
    X = bottleneck_residual_block(X, 3, [128, 128, 512])
    X = bottleneck_residual_block(X, 3, [128, 128, 512])
    
    # Step 4
    X = bottleneck_residual_block(X, 3, [256, 256, 1024], reduce=True, s=2)
    X = bottleneck_residual_block(X, 3, [256, 256, 1024])
    X = bottleneck_residual_block(X, 3, [256, 256, 1024])
    X = bottleneck_residual_block(X, 3, [256, 256, 1024])
    X = bottleneck_residual_block(X, 3, [256, 256, 1024])
    X = bottleneck_residual_block(X, 3, [256, 256, 1024])
    
    # Step 5
    X = bottleneck_residual_block(X, 3, [512, 512, 2048], reduce=True, s=2)
    X = bottleneck_residual_block(X, 3, [512, 512, 2048])
    X = bottleneck_residual_block(X, 3, [512, 512, 2048])
    
    X = AveragePooling2D((1,1))(X)
    
    X = Flatten()(X)
    X = Dense(classes, activation='softmax', name='fc' + str(classes))(X)
    
    model = keras.Model(inputs = X_input, outputs = X, name='ResNet50')
    
    return model

# %%
model = ResNet50(input_shape=(32,32,3), classes=10)
model.summary()
# Out:
# Metal device set to: Apple M2
# 2023-03-19 12:29:07.861737: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-19 12:29:07.862178: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "ResNet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv1 (Conv2D)                 (None, 13, 13, 64)   9472        ['input_1[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 13, 13, 64)   256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 13, 13, 64)   0           ['bn_conv1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 6, 6, 64)     0           ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 6, 6, 64)     4160        ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 6, 6, 64)    256         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 6, 6, 64)     0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 6, 6, 64)     36928       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 6, 6, 64)    256         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 6, 6, 64)     0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 6, 6, 256)    16640       ['activation_2[0][0]']
#
#  conv2d (Conv2D)                (None, 6, 6, 256)    16640       ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 6, 6, 256)   1024        ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization (BatchNorm  (None, 6, 6, 256)   1024        ['conv2d[0][0]']
#  alization)
#
#  add (Add)                      (None, 6, 6, 256)    0           ['batch_normalization_3[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  activation_3 (Activation)      (None, 6, 6, 256)    0           ['add[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 6, 6, 64)     16448       ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 6, 6, 64)    256         ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 6, 6, 64)     0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 6, 6, 64)     36928       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 6, 6, 64)    256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 6, 6, 64)     0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 6, 6, 256)    16640       ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 6, 6, 256)   1024        ['conv2d_6[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 6, 6, 256)    0           ['batch_normalization_6[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 6, 6, 256)    0           ['add_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 6, 6, 64)     16448       ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 6, 6, 64)    256         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 6, 6, 64)     0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 6, 6, 64)     36928       ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 6, 6, 64)    256         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 6, 6, 64)     0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 6, 6, 256)    16640       ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 6, 6, 256)   1024        ['conv2d_9[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 6, 6, 256)    0           ['batch_normalization_9[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 6, 6, 256)    0           ['add_2[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 3, 3, 128)    32896       ['activation_9[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 3, 3, 128)   512         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 3, 3, 128)    0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 3, 3, 128)    147584      ['activation_10[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 3, 3, 128)   512         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 3, 3, 128)    0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 3, 3, 512)    66048       ['activation_11[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 3, 3, 512)    131584      ['activation_9[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 3, 3, 512)   2048        ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_10 (BatchN  (None, 3, 3, 512)   2048        ['conv2d_10[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 3, 3, 512)    0           ['batch_normalization_13[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  activation_12 (Activation)     (None, 3, 3, 512)    0           ['add_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 3, 3, 128)    65664       ['activation_12[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 3, 3, 128)   512         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 3, 3, 128)    0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 3, 3, 128)    147584      ['activation_13[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 3, 3, 128)   512         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 3, 3, 128)    0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 3, 3, 512)    66048       ['activation_14[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 3, 3, 512)   2048        ['conv2d_16[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 3, 3, 512)    0           ['batch_normalization_16[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 3, 3, 512)    0           ['add_4[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 3, 3, 128)    65664       ['activation_15[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 3, 3, 128)   512         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 3, 3, 128)    0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 3, 3, 128)    147584      ['activation_16[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 3, 3, 128)   512         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 3, 3, 128)    0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 3, 3, 512)    66048       ['activation_17[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 3, 3, 512)   2048        ['conv2d_19[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 3, 3, 512)    0           ['batch_normalization_19[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 3, 3, 512)    0           ['add_5[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 3, 3, 128)    65664       ['activation_18[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 3, 3, 128)   512         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 3, 3, 128)    0           ['batch_normalization_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 3, 3, 128)    147584      ['activation_19[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 3, 3, 128)   512         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 3, 3, 128)    0           ['batch_normalization_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 3, 3, 512)    66048       ['activation_20[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 3, 3, 512)   2048        ['conv2d_22[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 3, 3, 512)    0           ['batch_normalization_22[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 3, 3, 512)    0           ['add_6[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 2, 2, 256)    131328      ['activation_21[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_22[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 2, 2, 1024)   263168      ['activation_23[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 2, 2, 1024)   525312      ['activation_21[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 2, 2, 1024)  4096        ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 2, 2, 1024)  4096        ['conv2d_23[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 2, 2, 1024)   0           ['batch_normalization_26[0][0]',
#                                                                   'batch_normalization_23[0][0]']
#
#  activation_24 (Activation)     (None, 2, 2, 1024)   0           ['add_7[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 2, 2, 256)    262400      ['activation_24[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_25[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 2, 2, 1024)   263168      ['activation_26[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 2, 2, 1024)  4096        ['conv2d_29[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 2, 2, 1024)   0           ['batch_normalization_29[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_27 (Activation)     (None, 2, 2, 1024)   0           ['add_8[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 2, 2, 256)    262400      ['activation_27[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_30[0][0]']
#  ormalization)
#  activation_28 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_28[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 2, 2, 1024)   263168      ['activation_29[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 2, 2, 1024)  4096        ['conv2d_32[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 2, 2, 1024)   0           ['batch_normalization_32[0][0]',
#                                                                   'activation_27[0][0]']
#
#  activation_30 (Activation)     (None, 2, 2, 1024)   0           ['add_9[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 2, 2, 256)    262400      ['activation_30[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_31[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 2, 2, 1024)   263168      ['activation_32[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 2, 2, 1024)  4096        ['conv2d_35[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 2, 2, 1024)   0           ['batch_normalization_35[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 2, 2, 1024)   0           ['add_10[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 2, 2, 256)    262400      ['activation_33[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_34[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_37[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 2, 2, 1024)   263168      ['activation_35[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 2, 2, 1024)  4096        ['conv2d_38[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 2, 2, 1024)   0           ['batch_normalization_38[0][0]',
#                                                                   'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 2, 2, 1024)   0           ['add_11[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 2, 2, 256)    262400      ['activation_36[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_37[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 2, 2, 1024)   263168      ['activation_38[0][0]']
#  batch_normalization_41 (BatchN  (None, 2, 2, 1024)  4096        ['conv2d_41[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 2, 2, 1024)   0           ['batch_normalization_41[0][0]',
#                                                                   'activation_36[0][0]']
#
#  activation_39 (Activation)     (None, 2, 2, 1024)   0           ['add_12[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 1, 1, 512)    524800      ['activation_39[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_40[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 1, 1, 2048)   1050624     ['activation_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 1, 1, 2048)   2099200     ['activation_39[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 1, 1, 2048)  8192        ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_42 (BatchN  (None, 1, 1, 2048)  8192        ['conv2d_42[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 1, 1, 2048)   0           ['batch_normalization_45[0][0]',
#                                                                   'batch_normalization_42[0][0]']
#
#  activation_42 (Activation)     (None, 1, 1, 2048)   0           ['add_13[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 1, 1, 512)    1049088     ['activation_42[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_46[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_43[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 1, 1, 2048)   1050624     ['activation_44[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 1, 1, 2048)  8192        ['conv2d_48[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 1, 1, 2048)   0           ['batch_normalization_48[0][0]',
#                                                                   'activation_42[0][0]']
#
#  activation_45 (Activation)     (None, 1, 1, 2048)   0           ['add_14[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 1, 1, 512)    1049088     ['activation_45[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_49[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_46[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 1, 1, 2048)   1050624     ['activation_47[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 1, 1, 2048)  8192        ['conv2d_51[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 1, 1, 2048)   0           ['batch_normalization_51[0][0]',
#                                                                   'activation_45[0][0]']
#  activation_48 (Activation)     (None, 1, 1, 2048)   0           ['add_15[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 2048)  0           ['activation_48[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 2048)         0           ['average_pooling2d[0][0]']
#
#  fc10 (Dense)                   (None, 10)           20490       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 23,608,202
# Trainable params: 23,555,082
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
import os

save_dir = os.path.join(os.getcwd(), 'ResNet')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
filepath1 = os.path.join(save_dir, 'ResNet50.png')
keras.utils.plot_model(model=model,
                       to_file=filepath1,
                       show_shapes=True
                      )

# %%
from keras.callbacks import ReduceLROnPlateau
import numpy as np

epochs = 5 #200
batch_size = 256

reduce_lr = ReduceLROnPlateau(modnitor='val_loss',
                              factor=np.sqrt(0.1),
                              patience=5,
                              min_lr=0.5e-6
                             )

model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.SGD(),
              metrics=['accuracy']
             )

model.fit(x_train, y_train, batch_size=batch_size, validation_data=(x_val, y_val),
          epochs=epochs, callbacks=[reduce_lr]
         )
# Out:
# Epoch 1/5
# 2023-03-19 12:35:37.702818: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-19 12:35:39.071117: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 227/227 [==============================] - ETA: 0s - loss: 0.5351 - accuracy: 0.8486
# 2023-03-19 12:37:06.903065: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 227/227 [==============================] - 91s 379ms/step - loss: 0.5351 - accuracy: 0.8486 - val_loss: 1.7583 - val_accuracy: 0.4170 - lr: 0.0100
# Epoch 2/5
# 227/227 [==============================] - 84s 372ms/step - loss: 0.1036 - accuracy: 0.9684 - val_loss: 0.0890 - val_accuracy: 0.9760 - lr: 0.0100
# Epoch 3/5
# 227/227 [==============================] - 84s 371ms/step - loss: 0.0484 - accuracy: 0.9849 - val_loss: 0.0667 - val_accuracy: 0.9820 - lr: 0.0100
# Epoch 4/5
# 227/227 [==============================] - 84s 370ms/step - loss: 0.0244 - accuracy: 0.9922 - val_loss: 0.0793 - val_accuracy: 0.9830 - lr: 0.0100
# Epoch 5/5
# 227/227 [==============================] - 91s 399ms/step - loss: 0.0118 - accuracy: 0.9966 - val_loss: 0.0751 - val_accuracy: 0.9840 - lr: 0.0100
