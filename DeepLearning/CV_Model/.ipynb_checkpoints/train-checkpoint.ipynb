# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# # MNIST

# %% [markdown]
# ## Load Data

# %%
import tensorflow as tf
from tensorflow import keras
from keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

unique, counts = np.unique(y_train, return_counts=True)
print(f"Train Labels: {dict(zip(unique, counts))}")

unique, counts = np.unique(y_test, return_counts=True)
print(f"Test Labels: {dict(zip(unique, counts))}")
# Out:
# Train Labels: {0: 5923, 1: 6742, 2: 5958, 3: 6131, 4: 5842, 5: 5421, 6: 5918, 7: 6265, 8: 5851, 9: 5949}
# Test Labels: {0: 980, 1: 1135, 2: 1032, 3: 1010, 4: 982, 5: 892, 6: 958, 7: 1028, 8: 974, 9: 1009}

# %%
indexes = np.random.randint(0, x_train.shape[0], size=9)
images = x_train[indexes]
labels = y_train[indexes]

# %%
plt.figure(figsize=(5, 5))
for i in range(len(indexes)):
    plt.subplot(3, 3, i+1)
    plt.imshow(images[i], cmap='gray')
    plt.axis('off')
    plt.title(labels[i])
plt.show()

# %% [markdown]
# ## Preprocessing

# %%
num_labels = len(unique)

y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

x_train = np.reshape(x_train, [-1, x_train.shape[1], x_train.shape[2], 1])
x_test = np.reshape(x_test, [-1, x_test.shape[1], x_test.shape[2], 1])
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

input_shape = x_train.shape[1:]

# %% [markdown]
# # LeNet-5

# %% [markdown]
# ### Input Shape: 28x28x1(MNIST)
# **Convolution Layers**
#
# 1. ConV_1 (5x5, s=1, activation='tanh', filters=  6, padding='same')
# 2. Pooling_2 (f=2, s=2, padding='valid')
# 3. ConV_3 (5x5, s=1, activation='tanh', filters= 16, padding='valid')
# 4. Pooling_4 (f=2, s=2, padding='valid')
# 5. ConV_5 (5x5, s=1, activation='tanh', filters=120, padding='valid')
#
# **Fully Connected Layers**
#
# 6. Dense(units=84, activation='tanh')
#
# **Outputs**
#
# 7. Dense(units=10, activation='softmax')

# %%
from LeNet import build_lenet_5, lr_schedule

# %%
model = build_lenet_5(input_shape=input_shape)
model.summary()
# Out:
# Model: "LeNet_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 6)         156
#
#  average_pooling2d_2 (Averag  (None, 14, 14, 6)        0
#  ePooling2D)
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 16)        2416
#
#  average_pooling2d_3 (Averag  (None, 5, 5, 16)         0
#  ePooling2D)
#
#  conv2d_5 (Conv2D)           (None, 1, 1, 120)         48120
#
#  flatten_1 (Flatten)         (None, 120)               0
#
#  dense_2 (Dense)             (None, 84)                10164
#
#  dense_3 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
"""
keras.utils.plot_model(model=model,
                       to_file='LeNet5.png',
                       show_shapes=True
                      )
"""

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
import os

save_dir = os.path.join(os.getcwd(), 'save_models')
model_name = 'mnist_lesnet_v5.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

lr_scheduler = LearningRateScheduler(lr_schedule)
checkpoints = ModelCheckpoint(filepath=filepath,
                              monitor='val_accuracy',
                              verbose=1,
                              save_best_only=True
                             )
callbacks = [checkpoints, lr_scheduler]

model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy']
             )

# %%
hist = model.fit(x_train, y_train, 
                 batch_size=32, 
                 epochs=20,
                 validation_data=(x_test, y_test),
                 callbacks=callbacks,
                 verbose=2,
                 shuffle=True
                )
# Out:
# Epoch 1/20
# 2023-03-16 19:58:16.388220: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-03-16 19:58:31.242165: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_accuracy improved from -inf to 0.57940, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.001.h5
# 1875/1875 - 17s - loss: 2.2277 - accuracy: 0.3279 - val_loss: 2.1048 - val_accuracy: 0.5794 - lr: 5.0000e-04 - 17s/epoch - 9ms/step
# Epoch 2/20
#
# Epoch 2: val_accuracy improved from 0.57940 to 0.72470, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.002.h5
# 1875/1875 - 17s - loss: 1.8387 - accuracy: 0.6527 - val_loss: 1.4798 - val_accuracy: 0.7247 - lr: 5.0000e-04 - 17s/epoch - 9ms/step
# Epoch 3/20
#
# Epoch 3: val_accuracy improved from 0.72470 to 0.79540, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.003.h5
# 1875/1875 - 16s - loss: 1.1995 - accuracy: 0.7521 - val_loss: 0.9614 - val_accuracy: 0.7954 - lr: 5.0000e-04 - 16s/epoch - 9ms/step
# Epoch 4/20
#
# Epoch 4: val_accuracy improved from 0.79540 to 0.81440, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.004.h5
# 1875/1875 - 16s - loss: 0.9201 - accuracy: 0.7973 - val_loss: 0.8530 - val_accuracy: 0.8144 - lr: 2.0000e-04 - 16s/epoch - 9ms/step
# Epoch 5/20
#
# Epoch 5: val_accuracy improved from 0.81440 to 0.82980, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.005.h5
# 1875/1875 - 16s - loss: 0.8267 - accuracy: 0.8131 - val_loss: 0.7732 - val_accuracy: 0.8298 - lr: 2.0000e-04 - 16s/epoch - 9ms/step
# Epoch 6/20
#
# Epoch 6: val_accuracy improved from 0.82980 to 0.84020, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.006.h5
# 1875/1875 - 17s - loss: 0.7566 - accuracy: 0.8260 - val_loss: 0.7120 - val_accuracy: 0.8402 - lr: 2.0000e-04 - 17s/epoch - 9ms/step
# Epoch 7/20
#
# Epoch 7: val_accuracy improved from 0.84020 to 0.84200, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.007.h5
# 1875/1875 - 16s - loss: 0.7203 - accuracy: 0.8319 - val_loss: 0.6989 - val_accuracy: 0.8420 - lr: 5.0000e-05 - 16s/epoch - 9ms/step
# Epoch 8/20
#
# Epoch 8: val_accuracy improved from 0.84200 to 0.84310, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.008.h5
# 1875/1875 - 16s - loss: 0.7074 - accuracy: 0.8344 - val_loss: 0.6864 - val_accuracy: 0.8431 - lr: 5.0000e-05 - 16s/epoch - 9ms/step
# Epoch 9/20
#
# Epoch 9: val_accuracy improved from 0.84310 to 0.84530, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.009.h5
# 1875/1875 - 16s - loss: 0.6952 - accuracy: 0.8367 - val_loss: 0.6746 - val_accuracy: 0.8453 - lr: 5.0000e-05 - 16s/epoch - 9ms/step
# Epoch 10/20
#
# Epoch 10: val_accuracy improved from 0.84530 to 0.84670, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.010.h5
# 1875/1875 - 16s - loss: 0.6836 - accuracy: 0.8389 - val_loss: 0.6634 - val_accuracy: 0.8467 - lr: 5.0000e-05 - 16s/epoch - 9ms/step
# Epoch 11/20
#
# Epoch 11: val_accuracy improved from 0.84670 to 0.84730, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.011.h5
# 1875/1875 - 16s - loss: 0.6769 - accuracy: 0.8400 - val_loss: 0.6612 - val_accuracy: 0.8473 - lr: 1.0000e-05 - 16s/epoch - 9ms/step
# Epoch 12/20
#
# Epoch 12: val_accuracy improved from 0.84730 to 0.84790, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.012.h5
# 1875/1875 - 17s - loss: 0.6747 - accuracy: 0.8405 - val_loss: 0.6590 - val_accuracy: 0.8479 - lr: 1.0000e-05 - 17s/epoch - 9ms/step
# Epoch 13/20
#
# Epoch 13: val_accuracy improved from 0.84790 to 0.84850, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.013.h5
# 1875/1875 - 16s - loss: 0.6725 - accuracy: 0.8410 - val_loss: 0.6569 - val_accuracy: 0.8485 - lr: 1.0000e-05 - 16s/epoch - 9ms/step
# Epoch 14/20
#
# Epoch 14: val_accuracy improved from 0.84850 to 0.84930, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.014.h5
# 1875/1875 - 16s - loss: 0.6704 - accuracy: 0.8413 - val_loss: 0.6548 - val_accuracy: 0.8493 - lr: 1.0000e-05 - 16s/epoch - 9ms/step
# Epoch 15/20
#
# Epoch 15: val_accuracy improved from 0.84930 to 0.85000, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.015.h5
# 1875/1875 - 16s - loss: 0.6683 - accuracy: 0.8416 - val_loss: 0.6527 - val_accuracy: 0.8500 - lr: 1.0000e-05 - 16s/epoch - 9ms/step
# Epoch 16/20
#
# Epoch 16: val_accuracy improved from 0.85000 to 0.85030, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.016.h5
# 1875/1875 - 16s - loss: 0.6662 - accuracy: 0.8420 - val_loss: 0.6506 - val_accuracy: 0.8503 - lr: 1.0000e-05 - 16s/epoch - 9ms/step
# Epoch 17/20
#
# Epoch 17: val_accuracy improved from 0.85030 to 0.85070, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.017.h5
# 1875/1875 - 16s - loss: 0.6641 - accuracy: 0.8424 - val_loss: 0.6485 - val_accuracy: 0.8507 - lr: 1.0000e-05 - 16s/epoch - 9ms/step
# Epoch 18/20
#
# Epoch 18: val_accuracy improved from 0.85070 to 0.85120, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.018.h5
# 1875/1875 - 17s - loss: 0.6620 - accuracy: 0.8430 - val_loss: 0.6465 - val_accuracy: 0.8512 - lr: 1.0000e-05 - 17s/epoch - 9ms/step
# Epoch 19/20
#
# Epoch 19: val_accuracy improved from 0.85120 to 0.85140, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.019.h5
# 1875/1875 - 16s - loss: 0.6600 - accuracy: 0.8435 - val_loss: 0.6445 - val_accuracy: 0.8514 - lr: 1.0000e-05 - 16s/epoch - 9ms/step
# Epoch 20/20
#
# Epoch 20: val_accuracy improved from 0.85140 to 0.85210, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/save_models/mnist_lesnet_v5.020.h5
# 1875/1875 - 17s - loss: 0.6580 - accuracy: 0.8440 - val_loss: 0.6424 - val_accuracy: 0.8521 - lr: 1.0000e-05 - 17s/epoch - 9ms/step

# %%
loss, acc = model.evaluate(x_test, y_test, batch_size=32)
print(f"Test accuracy: {(100*acc):>.1f}%")
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6424 - accuracy: 0.8521
# Test accuracy: 85.2%

# %%
plt.plot(hist.history['loss'], 'b-', label='loss')
plt.plot(hist.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.xticks(range(20))
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(hist.history['accuracy'], 'b-', label='acc')
plt.plot(hist.history['val_accuracy'], 'r--', label='val_acc')
plt.xlabel('Epoch')
plt.xticks(range(20))
plt.grid()
plt.legend()
plt.show()

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
new_model = build_lenet_5(input_shape=input_shape)
new_model.compile(loss='categorical_crossentropy',
                  optimizer='sgd',
                  metrics=['accuracy']
                 )

# %%
new_model.evaluate(x_test,y_test)
# Out:
#  17/313 [>.............................] - ETA: 1s - loss: 2.3176 - accuracy: 0.0754
# 2023-03-16 20:05:29.807979: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 2s 6ms/step - loss: 2.3239 - accuracy: 0.0914
# [2.3238861560821533, 0.09140000492334366]

# %%
log_dir = 'log/lenet_5'
tensorboard_cb = keras.callbacks.TensorBoard(log_dir, histogram_freq=1)

# %%
new_model.fit(x_train, y_train,
              epochs=20,
              batch_size=32,
              validation_data=(x_test, y_test),
              callbacks=[tensorboard_cb]
             )
# Out:
# Epoch 1/20
#    1/1875 [..............................] - ETA: 8:36 - loss: 2.3039 - accuracy: 0.0938
# 2023-03-16 20:07:41.789149: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.6485 - accuracy: 0.8320 - val_loss: 0.2978 - val_accuracy: 0.9176
# Epoch 2/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2682 - accuracy: 0.9204 - val_loss: 0.2164 - val_accuracy: 0.9368
# Epoch 3/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.2016 - accuracy: 0.9399 - val_loss: 0.1642 - val_accuracy: 0.9519
# Epoch 4/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.1577 - accuracy: 0.9530 - val_loss: 0.1337 - val_accuracy: 0.9605
# Epoch 5/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.1280 - accuracy: 0.9621 - val_loss: 0.1093 - val_accuracy: 0.9682
# Epoch 6/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.1073 - accuracy: 0.9683 - val_loss: 0.0945 - val_accuracy: 0.9713
# Epoch 7/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0922 - accuracy: 0.9730 - val_loss: 0.0814 - val_accuracy: 0.9750
# Epoch 8/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0810 - accuracy: 0.9760 - val_loss: 0.0753 - val_accuracy: 0.9757
# Epoch 9/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0721 - accuracy: 0.9791 - val_loss: 0.0680 - val_accuracy: 0.9782
# Epoch 10/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0655 - accuracy: 0.9810 - val_loss: 0.0615 - val_accuracy: 0.9807
# Epoch 11/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0603 - accuracy: 0.9822 - val_loss: 0.0566 - val_accuracy: 0.9822
# Epoch 12/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0557 - accuracy: 0.9836 - val_loss: 0.0540 - val_accuracy: 0.9823
# Epoch 13/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0518 - accuracy: 0.9847 - val_loss: 0.0511 - val_accuracy: 0.9830
# Epoch 14/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0486 - accuracy: 0.9855 - val_loss: 0.0489 - val_accuracy: 0.9840
# Epoch 15/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0454 - accuracy: 0.9868 - val_loss: 0.0484 - val_accuracy: 0.9841
# Epoch 16/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0431 - accuracy: 0.9876 - val_loss: 0.0465 - val_accuracy: 0.9837
# Epoch 17/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0409 - accuracy: 0.9881 - val_loss: 0.0445 - val_accuracy: 0.9844
# Epoch 18/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0389 - accuracy: 0.9891 - val_loss: 0.0417 - val_accuracy: 0.9864
# Epoch 19/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0366 - accuracy: 0.9894 - val_loss: 0.0392 - val_accuracy: 0.9876
# Epoch 20/20
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0352 - accuracy: 0.9900 - val_loss: 0.0394 - val_accuracy: 0.9863

# %%
# %tensorboard --logdir $log_dir
# Out:
#       <iframe id="tensorboard-frame-ff98a3fc8baea8e1" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-ff98a3fc8baea8e1");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
"""
.save_weights(path)
.save(path)
keras.models.load_model(path)
"""

# %% [markdown]
# # AlexNet

# %% [markdown]
# ### Input Shape: 28x28x1(MNIST)
# **Convolution Layers**
#
# 1. ConV_1 (11x11, s=1, activation='relu', filters=  6, padding='same')
# 2. Pooling_2 (f=2, s=2, padding='valid')
# 3. ConV_3 (5x5, s=1, activation='relu', filters= 16, padding='valid')
# 4. Pooling_4 (f=2, s=2, padding='valid')
# 5. ConV_5 (3x3, s=1, activation='relu', filters=120, padding='valid')
# 6. ConV_6 (3x3, s=1, activation='relu', filters=120, padding='valid')
# 7. ConV_7 (3x3, s=1, activation='relu', filters=120, padding='valid')
# 8. Pooling_8x
#
#
# **Fully Connected Layers**
#
# 9. Dense(units=84, activation='tanh')
#
# **Outputs**
#
# 10. Dense(units=10, activation='softmax')

# %%
from tensorflow import keras
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Dropout

# %%
def build_alexnet(input_shape, num_classes=1000):
    inputs = keras.Input(shape=input_shape)
# 1-layer  
    x = Conv2D(kernel_size=11,
               strides=4,
               activation='relu',
               filters=96,
               padding='valid')(inputs)
    x = MaxPooling2D(pool_size=3,
                     strides=2)(x)
    first_layer = BatchNormalization()(x)
# 2-layer
    x = Conv2D(kernel_size=5,
               strides=1,
               kernel_regularizer=keras.regularizers.L2(0.0005),
               activation='relu',
               filters=256,
               padding='same')(first_layer)
    x = MaxPooling2D(pool_size=3,
                     strides=2,
                     padding='valid')(x)
    second_layer = BatchNormalization()(x)
# 3-layer   
    x = Conv2D(kernel_size=3,
               strides=1,
               kernel_regularizer=keras.regularizers.L2(0.0005),
               activation='relu',
               filters=384,
               padding='same')(second_layer)
    third_layer = BatchNormalization()(x)
# 4-layer 
    x = Conv2D(kernel_size=3,
               strides=1,
               kernel_regularizer=keras.regularizers.L2(0.0005),
               activation='relu',
               filters=384,
               padding='same')(third_layer)
    fourth_layer = BatchNormalization()(x)
# 5-layer
    x = Conv2D(kernel_size=3,
               strides=1,
               kernel_regularizer=keras.regularizers.L2(0.0005),
               activation='relu',
               filters=256,
               padding='same')(fourth_layer)
    x = BatchNormalization()(x)
    fifth_layer = MaxPooling2D(pool_size=3,
                               strides=2,
                               padding='valid'
                              )(x)
    
    x = Flatten()(fifth_layer)
    
    x = Dense(units=4096,
              activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(units=4096,
              activation='relu')(x)
    x = Dropout(0.5)(x)
    
    outputs = Dense(units=num_classes, activation='softmax')(x)
    
    model = keras.Model(inputs=inputs, outputs=outputs, name='AlexNet')
    
    return model

# %%
model = build_alexnet((227,227,3))
model.summary()
# Out:
# Model: "AlexNet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 227, 227, 3)]     0
#
#  conv2d_10 (Conv2D)          (None, 55, 55, 96)        34944
#
#  max_pooling2d_6 (MaxPooling  (None, 27, 27, 96)       0
#  2D)
#
#  batch_normalization_8 (Batc  (None, 27, 27, 96)       384
#  hNormalization)
#
#  conv2d_11 (Conv2D)          (None, 27, 27, 256)       614656
#
#  max_pooling2d_7 (MaxPooling  (None, 13, 13, 256)      0
#  2D)
#
#  batch_normalization_9 (Batc  (None, 13, 13, 256)      1024
#  hNormalization)
#
#  conv2d_12 (Conv2D)          (None, 13, 13, 384)       885120
#
#  batch_normalization_10 (Bat  (None, 13, 13, 384)      1536
#  chNormalization)
#
#  conv2d_13 (Conv2D)          (None, 13, 13, 384)       1327488
#
#  batch_normalization_11 (Bat  (None, 13, 13, 384)      1536
#  chNormalization)
#
#  conv2d_14 (Conv2D)          (None, 13, 13, 256)       884992
#
#  batch_normalization_12 (Bat  (None, 13, 13, 256)      1024
#  chNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_3 (Dense)             (None, 4096)              37752832
#
#  dropout_2 (Dropout)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 4096)              16781312
#
#  dropout_3 (Dropout)         (None, 4096)              0
#
#  dense_5 (Dense)             (None, 1000)              4097000
#
# =================================================================
# Total params: 62,383,848
# Trainable params: 62,381,096
# Non-trainable params: 2,752
# _________________________________________________________________

# %%
"""
keras.utils.plot_model(model=model,
                       to_file='AlexNet.png',
                       show_shapes=True
                      )
"""
