# %% [markdown]
# # VGG16_ImageNet

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
from tensorflow import keras
from keras.applications.vgg16 import VGG16

base_model = VGG16(weights="imagenet",
                   include_top=False,
                   input_shape=(224,224,3)
                  )
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in base_model.layers:
    layer.trainable = False
    
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from keras.layers import Dense, Flatten

last_layer = base_model.get_layer('block5_pool') # 마지막층에 접근
last_output = last_layer.output # 마지막 층의 출력을 다음 층의 입력으로

x = Flatten()(last_output)
x = Dense(5, activation='softmax', name='softmax')(x)

# %%
new_model = keras.Model(inputs=base_model.input, outputs=x)
new_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  softmax (Dense)             (None, 5)                 125445
#
# =================================================================
# Total params: 14,840,133
# Trainable params: 125,445
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

data_files = os.path.join(os.getcwd(),'transfer_lr_data_files')

train_imgs = np.load(data_files+'/target_images.npy')
train_labels = np.load(data_files+'/target_labels.npy')

test_imgs = np.load(data_files+'/test_images.npy')
test_labels = np.load(data_files+'/test_labels.npy')

print(train_imgs.shape)
print(train_labels[0])
# Out:
# (65, 224, 224, 3)
# [1. 0. 0. 0. 0.]

# %%
Dict = ['Hat', 'Cube', 'Card', 'Torch', 'screw']

# %%
n_train = train_imgs.shape[0]
n_test = test_imgs.shape[0]
idx = np.random.randint(0, n_train, size=9)
images = train_imgs[idx]
labels = train_labels[idx]

plt.figure(figsize=(5,5))
for i in range(len(idx)):
    plt.subplot(3, 3, i+1)
    plt.imshow(images[i], cmap='gray')
    plt.axis('off')
    plt.title("Label : {}".format(Dict[np.argmax(labels[i])]))
plt.show()

# %%
# %load_ext tensorboard

# %%
log_dir = 'log'
filepath3 = os.path.join(filepath1, log_dir)

tensorboard_cb = keras.callbacks.TensorBoard(filepath3, histogram_freq=1)

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
import math

# Model Checkpoints
model_name = 'transfer_lr.{epoch:02d}.h5'
filepath1 = os.path.join(os.getcwd(), 'transfer_lr')
if not os.path.isdir(filepath1):
    os.makedirs(filepath1)
    
filepath2 = os.path.join(filepath1, model_name)
checkpoints = ModelCheckpoint(filepath=filepath2,
                              monitor='val_accuracy',
                              verbose=1,
                              save_best_only=True
                             )

# Model lr_scheduler setting
initial_lrate = 0.01

def decay(epoch, steps=100):
    initial_lrate = 0.01
    drop = 0.96
    epochs_drop = 10
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

lr_scheduler = LearningRateScheduler(decay, verbose=1)

sgd = keras.optimizers.SGD(learning_rate=initial_lrate, momentum=0.9, nesterov=False)

# Tensorboard
log_dir = 'log'
filepath3 = os.path.join(filepath1, log_dir)
tensorboard_cb = keras.callbacks.TensorBoard(filepath3, histogram_freq=1)

# Compile and training
batch_size = 20
epochs = 50

new_model.compile(loss='categorical_crossentropy',
                  optimizer=sgd,
                  metrics=['accuracy']
                 )

hist = new_model.fit(train_imgs, train_labels, batch_size=batch_size, epochs=epochs,
                     validation_data=(test_imgs, test_labels), 
                     callbacks=[checkpoints, lr_scheduler, tensorboard_cb],
                     verbose=2,
                     shuffle=True
                    )
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.01.
# Epoch 1/300
# 2023-03-19 14:24:48.531932: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-19 14:24:48.800239: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-03-19 14:24:51.009938: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_accuracy improved from -inf to 0.11111, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/transfer_lr/transfer_lr.01.h5
# 4/4 - 4s - loss: 10.6040 - accuracy: 0.1692 - val_loss: 70.4091 - val_accuracy: 0.1111 - lr: 0.0100 - 4s/epoch - 955ms/step
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.01.
# Epoch 2/300
#
# Epoch 2: val_accuracy improved from 0.11111 to 0.55556, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/transfer_lr/transfer_lr.02.h5
# 4/4 - 2s - loss: 73.9998 - accuracy: 0.2462 - val_loss: 4.7972 - val_accuracy: 0.5556 - lr: 0.0100 - 2s/epoch - 530ms/step
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.01.
# Epoch 3/300
#
# Epoch 3: val_accuracy did not improve from 0.55556
# 4/4 - 2s - loss: 30.3364 - accuracy: 0.3846 - val_loss: 31.3925 - val_accuracy: 0.4444 - lr: 0.0100 - 2s/epoch - 519ms/step
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.01.
# Epoch 4/300
#
# Epoch 4: val_accuracy did not improve from 0.55556
# 4/4 - 2s - loss: 19.7695 - accuracy: 0.5231 - val_loss: 20.4655 - val_accuracy: 0.3333 - lr: 0.0100 - 2s/epoch - 482ms/step
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.01.
# Epoch 5/300
#
# Epoch 5: val_accuracy did not improve from 0.55556
# 4/4 - 2s - loss: 11.5665 - accuracy: 0.5077 - val_loss: 5.1381 - val_accuracy: 0.5556 - lr: 0.0100 - 2s/epoch - 461ms/step
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.01.
# Epoch 6/300
#
# Epoch 6: val_accuracy did not improve from 0.55556
# 4/4 - 2s - loss: 7.3483 - accuracy: 0.6308 - val_loss: 3.8000 - val_accuracy: 0.5556 - lr: 0.0100 - 2s/epoch - 476ms/step
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.01.
# Epoch 7/300
#
# Epoch 7: val_accuracy improved from 0.55556 to 1.00000, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/transfer_lr/transfer_lr.07.h5
# 4/4 - 2s - loss: 5.5056 - accuracy: 0.7385 - val_loss: 0.0011 - val_accuracy: 1.0000 - lr: 0.0100 - 2s/epoch - 469ms/step
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.01.
# Epoch 8/300
#
# Epoch 8: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 10.1331 - accuracy: 0.7385 - val_loss: 1.2187 - val_accuracy: 0.8889 - lr: 0.0100 - 2s/epoch - 476ms/step
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.01.
# Epoch 9/300
#
# Epoch 9: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 2.5090 - accuracy: 0.8000 - val_loss: 18.6395 - val_accuracy: 0.6667 - lr: 0.0100 - 2s/epoch - 460ms/step
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0096.
# Epoch 10/300
#
# Epoch 10: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 7.1847 - accuracy: 0.8154 - val_loss: 0.2510 - val_accuracy: 0.8889 - lr: 0.0096 - 2s/epoch - 463ms/step
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0096.
# Epoch 11/300
#
# Epoch 11: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.2223 - accuracy: 0.9692 - val_loss: 3.5508 - val_accuracy: 0.7778 - lr: 0.0096 - 2s/epoch - 444ms/step
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0096.
# Epoch 12/300
#
# Epoch 12: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 3.6038 - accuracy: 0.8154 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0096 - 2s/epoch - 463ms/step
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0096.
# Epoch 13/300
#
# Epoch 13: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.7540 - accuracy: 0.9538 - val_loss: 9.7513 - val_accuracy: 0.6667 - lr: 0.0096 - 2s/epoch - 490ms/step
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0096.
# Epoch 14/300
#
# Epoch 14: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 2.3173 - accuracy: 0.8308 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0096 - 2s/epoch - 491ms/step
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0096.
# Epoch 15/300
#
# Epoch 15: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.1333 - accuracy: 0.9846 - val_loss: 2.7543e-08 - val_accuracy: 1.0000 - lr: 0.0096 - 2s/epoch - 498ms/step
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0096.
# Epoch 16/300
#
# Epoch 16: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 3.4065 - accuracy: 0.8308 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0096 - 2s/epoch - 458ms/step
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0096.
# Epoch 17/300
#
# Epoch 17: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.5260 - accuracy: 0.9538 - val_loss: 15.8269 - val_accuracy: 0.5556 - lr: 0.0096 - 2s/epoch - 470ms/step
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0096.
# Epoch 18/300
#
# Epoch 18: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 3.0612 - accuracy: 0.8462 - val_loss: 1.0191e-06 - val_accuracy: 1.0000 - lr: 0.0096 - 2s/epoch - 462ms/step
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.0096.
# Epoch 19/300
#
# Epoch 19: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.7115 - accuracy: 0.9231 - val_loss: 0.5452 - val_accuracy: 0.8889 - lr: 0.0096 - 2s/epoch - 489ms/step
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 20/300
#
# Epoch 20: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.9785 - accuracy: 0.9538 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0092 - 2s/epoch - 494ms/step
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 21/300
#
# Epoch 21: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0092 - 2s/epoch - 462ms/step
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 22/300
#
# Epoch 22: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.1935e-07 - val_accuracy: 1.0000 - lr: 0.0092 - 2s/epoch - 460ms/step
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 23/300
#
# Epoch 23: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.5051 - accuracy: 0.9538 - val_loss: 5.8942e-06 - val_accuracy: 1.0000 - lr: 0.0092 - 2s/epoch - 461ms/step
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 24/300
#
# Epoch 24: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.8562 - accuracy: 0.9385 - val_loss: 2.3318 - val_accuracy: 0.8889 - lr: 0.0092 - 2s/epoch - 518ms/step
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 25/300
#
# Epoch 25: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 1.2986 - accuracy: 0.9231 - val_loss: 3.3781 - val_accuracy: 0.7778 - lr: 0.0092 - 2s/epoch - 496ms/step
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 26/300
#
# Epoch 26: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 3.7397 - accuracy: 0.8308 - val_loss: 0.8409 - val_accuracy: 0.8889 - lr: 0.0092 - 2s/epoch - 453ms/step
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 27/300
#
# Epoch 27: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.4421 - accuracy: 0.9692 - val_loss: 0.0805 - val_accuracy: 0.8889 - lr: 0.0092 - 2s/epoch - 452ms/step
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 28/300
#
# Epoch 28: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.2197 - accuracy: 0.9846 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0092 - 2s/epoch - 472ms/step
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 29/300
#
# Epoch 29: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.4049 - accuracy: 0.9538 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0092 - 2s/epoch - 480ms/step
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.008847359999999999.
# Epoch 30/300
#
# Epoch 30: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 452ms/step
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.008847359999999999.
# Epoch 31/300
#
# Epoch 31: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0255 - accuracy: 0.9846 - val_loss: 4.5905e-08 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 447ms/step
# Epoch 32: LearningRateScheduler setting learning rate to 0.008847359999999999.
# Epoch 32/300
#
# Epoch 32: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.1197 - accuracy: 0.9692 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 501ms/step
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.008847359999999999.
# Epoch 33/300
#
# Epoch 33: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 7.6273e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 467ms/step
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.008847359999999999.
# Epoch 34/300
#
# Epoch 34: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 441ms/step
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.008847359999999999.
# Epoch 35/300
#
# Epoch 35: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 481ms/step
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.008847359999999999.
# Epoch 36/300
#
# Epoch 36: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 446ms/step
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.008847359999999999.
# Epoch 37/300
#
# Epoch 37: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 441ms/step
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.008847359999999999.
# Epoch 38/300
#
# Epoch 38: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 484ms/step
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.008847359999999999.
# Epoch 39/300
#
# Epoch 39: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 486ms/step
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.008493465599999998.
# Epoch 40/300
#
# Epoch 40: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 484ms/step
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.008493465599999998.
# Epoch 41/300
#
# Epoch 41: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 479ms/step
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.008493465599999998.
# Epoch 42/300
#
# Epoch 42: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 512ms/step
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.008493465599999998.
# Epoch 43/300
#
# Epoch 43: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 459ms/step
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.008493465599999998.
# Epoch 44/300
#
# Epoch 44: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 474ms/step
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.008493465599999998.
# Epoch 45/300
#
# Epoch 45: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 459ms/step
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.008493465599999998.
# Epoch 46/300
#
# Epoch 46: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 442ms/step
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.008493465599999998.
# Epoch 47/300
#
# Epoch 47: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 466ms/step
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.008493465599999998.
# Epoch 48/300
#
# Epoch 48: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 491ms/step
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.008493465599999998.
# Epoch 49/300
#
# Epoch 49: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 471ms/step
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.008153726976.
# Epoch 50/300
#
# Epoch 50: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0082 - 2s/epoch - 454ms/step
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.008153726976.
# Epoch 51/300
#
# Epoch 51: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0082 - 2s/epoch - 488ms/step
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.008153726976.
# Epoch 52/300
#
# Epoch 52: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0082 - 2s/epoch - 481ms/step
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.008153726976.
# Epoch 53/300
#
# Epoch 53: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0082 - 2s/epoch - 497ms/step
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.008153726976.
# Epoch 54/300
#
# Epoch 54: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0082 - 2s/epoch - 496ms/step
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.008153726976.
# Epoch 55/300
#
# Epoch 55: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0082 - 2s/epoch - 491ms/step
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.008153726976.
# Epoch 56/300
#
# Epoch 56: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0082 - 2s/epoch - 473ms/step
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.008153726976.
# Epoch 57/300
#
# Epoch 57: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0082 - 2s/epoch - 495ms/step
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.008153726976.
# Epoch 58/300
#
# Epoch 58: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0082 - 2s/epoch - 497ms/step
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.008153726976.
# Epoch 59/300
#
# Epoch 59: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0082 - 2s/epoch - 488ms/step
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.007827577896959998.
# Epoch 60/300
#
# Epoch 60: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0078 - 2s/epoch - 471ms/step
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.007827577896959998.
# Epoch 61/300
#
# Epoch 61: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0078 - 2s/epoch - 492ms/step
# Epoch 62: LearningRateScheduler setting learning rate to 0.007827577896959998.
# Epoch 62/300
#
# Epoch 62: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0078 - 2s/epoch - 499ms/step
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.007827577896959998.
# Epoch 63/300
#
# Epoch 63: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0078 - 2s/epoch - 497ms/step
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.007827577896959998.
# Epoch 64/300
#
# Epoch 64: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0078 - 2s/epoch - 525ms/step
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.007827577896959998.
# Epoch 65/300
#
# Epoch 65: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0078 - 2s/epoch - 476ms/step
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.007827577896959998.
# Epoch 66/300
#
# Epoch 66: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0078 - 2s/epoch - 472ms/step
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.007827577896959998.
# Epoch 67/300
#
# Epoch 67: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0078 - 2s/epoch - 451ms/step
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.007827577896959998.
# Epoch 68/300
#
# Epoch 68: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0078 - 2s/epoch - 482ms/step
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.007827577896959998.
# Epoch 69/300
#
# Epoch 69: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0078 - 2s/epoch - 507ms/step
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.007514474781081598.
# Epoch 70/300
#
# Epoch 70: val_accuracy did not improve from 1.00000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 40
#      34 # Compile and training
#      35 new_model.compile(loss='categorical_crossentropy',
#      36                   optimizer=sgd,
#      37                   metrics=['accuracy']
#      38                  )
# ---> 40 hist = new_model.fit(train_imgs, train_labels, batch_size=batch_size, epochs=epochs,
#      41                      validation_data=(test_imgs, test_labels),
#      42                      callbacks=[checkpoints, lr_scheduler, tensorboard_cb],
#      43                      verbose=2,
#      44                      shuffle=True
#      45                     )
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/keras/engine/training.py:1435, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1432   val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1433   epoch_logs.update(val_logs)
# -> 1435 callbacks.on_epoch_end(epoch, epoch_logs)
#    1436 training_logs = epoch_logs
#    1437 if self.stop_training:
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/keras/callbacks.py:416, in CallbackList.on_epoch_end(self, epoch, logs)
#     414 logs = self._process_logs(logs)
#     415 for callback in self.callbacks:
# --> 416   callback.on_epoch_end(epoch, logs)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/keras/callbacks.py:2506, in TensorBoard.on_epoch_end(self, epoch, logs)
#    2503 self._log_epoch_metrics(epoch, logs)
#    2505 if self.histogram_freq and epoch % self.histogram_freq == 0:
# -> 2506   self._log_weights(epoch)
#    2508 if self.embeddings_freq and epoch % self.embeddings_freq == 0:
#    2509   self._log_embeddings(epoch)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/keras/callbacks.py:2574, in TensorBoard._log_weights(self, epoch)
#    2572 for weight in layer.weights:
#    2573   weight_name = weight.name.replace(':', '_')
# -> 2574   tf.summary.histogram(weight_name, weight, step=epoch)
#    2575   if self.write_images:
#    2576     self._log_weight_as_image(weight, weight_name, epoch)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorboard/plugins/histogram/summary_v2.py:194, in histogram(name, data, step, buckets, description)
#     190 @lazy_tensor_creator.LazyTensorCreator
#     191 def lazy_tensor():
#     192     return _buckets(data, buckets)
# --> 194 return tf.summary.write(
#     195     tag=tag,
#     196     tensor=lazy_tensor,
#     197     step=step,
#     198     metadata=summary_metadata,
#     199 )
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/summary_ops_v2.py:767, in write(tag, tensor, step, metadata, name)
#     764     with ops.control_dependencies([write_summary_op]):
#     765       return constant_op.constant(True)
# --> 767 op = smart_cond.smart_cond(
#     768     should_record_summaries(), record, _nothing, name="summary_cond")
#     769 if not context.executing_eagerly():
#     770   ops.add_to_collection(ops.GraphKeys._SUMMARY_COLLECTION, op)  # pylint: disable=protected-access
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/smart_cond.py:53, in smart_cond(pred, true_fn, false_fn, name)
#      51 if pred_value is not None:
#      52   if pred_value:
# ---> 53     return true_fn()
#      54   else:
#      55     return false_fn()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/summary_ops_v2.py:755, in write.<locals>.record()
#     753 # Note the identity to move the tensor to the CPU.
#     754 with ops.device("cpu:0"):
# --> 755   summary_tensor = tensor() if callable(tensor) else array_ops.identity(
#     756       tensor)
#     757   write_summary_op = gen_summary_ops.write_summary(
#     758       _summary_state.writer._resource,  # pylint: disable=protected-access
#     759       step,
#    (...)
#     762       serialized_metadata,
#     763       name=scope)
#     764   with ops.control_dependencies([write_summary_op]):
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorboard/util/lazy_tensor_creator.py:66, in LazyTensorCreator.__call__(self)
#      64         elif self._tensor is None:
#      65             self._tensor = _CALL_IN_PROGRESS_SENTINEL
# ---> 66             self._tensor = self._tensor_callable()
#      67 return self._tensor
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorboard/plugins/histogram/summary_v2.py:192, in histogram.<locals>.lazy_tensor()
#     190 @lazy_tensor_creator.LazyTensorCreator
#     191 def lazy_tensor():
# --> 192     return _buckets(data, buckets)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorboard/plugins/histogram/summary_v2.py:291, in _buckets(data, bucket_count)
#     285         return tf.transpose(a=tf.stack([edges, edges, bucket_counts]))
#     287     return tf.cond(
#     288         has_single_value, when_single_value, when_multiple_values
#     289     )
# --> 291 return tf.cond(is_empty, when_empty, when_nonempty)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/control_flow_ops.py:1452, in cond_for_tf_v2(pred, true_fn, false_fn, name)
#    1380 @tf_export("cond", v1=[])
#    1381 @dispatch.add_dispatch_support
#    1382 def cond_for_tf_v2(pred, true_fn=None, false_fn=None, name=None):
#    1383   """Return `true_fn()` if the predicate `pred` is true else `false_fn()`.
#    1384
#    1385   `true_fn` and `false_fn` both return lists of output tensors. `true_fn` and
#    (...)
#    1450
#    1451   """
# -> 1452   return cond(pred, true_fn=true_fn, false_fn=false_fn, strict=True, name=name)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:548, in deprecated_args.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     540         _PRINTED_WARNING[(func, arg_name)] = True
#     541       logging.warning(
#     542           'From %s: calling %s (from %s) with %s is deprecated and will '
#     543           'be removed %s.\nInstructions for updating:\n%s',
#    (...)
#     546           'in a future version' if date is None else ('after %s' % date),
#     547           instructions)
# --> 548 return func(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/control_flow_ops.py:1261, in cond(pred, true_fn, false_fn, strict, name, fn1, fn2)
#    1258   raise TypeError("'false_fn' must be callable.")
#    1260 if context.executing_eagerly():
# -> 1261   return _eager_cond_implementation(pred, true_fn, false_fn, strict, name)
#    1263 # Always enable control flow v2 if building a function, regardless of toggle.
#    1264 if util.EnableControlFlowV2(ops.get_default_graph()):
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/control_flow_ops.py:1150, in _eager_cond_implementation(pred, true_fn, false_fn, strict, name)
#    1148   result = true_fn()
#    1149 else:
# -> 1150   result = false_fn()
#    1151 if not strict:
#    1152   result = _UnpackIfSingleton(result)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorboard/plugins/histogram/summary_v2.py:287, in _buckets.<locals>.when_nonempty()
#     281     bucket_counts = tf.cast(
#     282         tf.concat([zeroes[:-1], [data_size]], 0)[:bucket_count],
#     283         dtype=tf.float64,
#     284     )
#     285     return tf.transpose(a=tf.stack([edges, edges, bucket_counts]))
# --> 287 return tf.cond(
#     288     has_single_value, when_single_value, when_multiple_values
#     289 )
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/control_flow_ops.py:1452, in cond_for_tf_v2(pred, true_fn, false_fn, name)
#    1380 @tf_export("cond", v1=[])
#    1381 @dispatch.add_dispatch_support
#    1382 def cond_for_tf_v2(pred, true_fn=None, false_fn=None, name=None):
#    1383   """Return `true_fn()` if the predicate `pred` is true else `false_fn()`.
#    1384
#    1385   `true_fn` and `false_fn` both return lists of output tensors. `true_fn` and
#    (...)
#    1450
#    1451   """
# -> 1452   return cond(pred, true_fn=true_fn, false_fn=false_fn, strict=True, name=name)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:548, in deprecated_args.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     540         _PRINTED_WARNING[(func, arg_name)] = True
#     541       logging.warning(
#     542           'From %s: calling %s (from %s) with %s is deprecated and will '
#     543           'be removed %s.\nInstructions for updating:\n%s',
#    (...)
#     546           'in a future version' if date is None else ('after %s' % date),
#     547           instructions)
# --> 548 return func(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/control_flow_ops.py:1261, in cond(pred, true_fn, false_fn, strict, name, fn1, fn2)
#    1258   raise TypeError("'false_fn' must be callable.")
#    1260 if context.executing_eagerly():
# -> 1261   return _eager_cond_implementation(pred, true_fn, false_fn, strict, name)
#    1263 # Always enable control flow v2 if building a function, regardless of toggle.
#    1264 if util.EnableControlFlowV2(ops.get_default_graph()):
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/control_flow_ops.py:1150, in _eager_cond_implementation(pred, true_fn, false_fn, strict, name)
#    1148   result = true_fn()
#    1149 else:
# -> 1150   result = false_fn()
#    1151 if not strict:
#    1152   result = _UnpackIfSingleton(result)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorboard/plugins/histogram/summary_v2.py:256, in _buckets.<locals>.when_nonempty.<locals>.when_multiple_values()
#     252 clamped_indices = tf.minimum(bucket_indices, bucket_count - 1)
#     253 # Use float64 instead of float32 to avoid accumulating floating point error
#     254 # later in tf.reduce_sum when summing more than 2^24 individual `1.0` values.
#     255 # See https://github.com/tensorflow/tensorflow/issues/51419 for details.
# --> 256 one_hots = tf.one_hot(
#     257     clamped_indices, depth=bucket_count, dtype=tf.float64
#     258 )
#     259 bucket_counts = tf.cast(
#     260     tf.reduce_sum(input_tensor=one_hots, axis=0),
#     261     dtype=tf.float64,
#     262 )
#     263 edges = tf.linspace(min_, max_, bucket_count + 1)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:4404, in one_hot(indices, depth, on_value, off_value, axis, dtype, name)
#    4400 if on_dtype != off_dtype:
#    4401   raise TypeError("dtype {0} of on_value does not match "
#    4402                   "dtype {1} of off_value".format(on_dtype, off_dtype))
# -> 4404 return gen_array_ops.one_hot(indices, depth, on_value, off_value, axis,
#    4405                              name)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/gen_array_ops.py:6399, in one_hot(indices, depth, on_value, off_value, axis, name)
#    6397 if tld.is_eager:
#    6398   try:
# -> 6399     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6400       _ctx, "OneHot", name, indices, depth, on_value, off_value, "axis",
#    6401       axis)
#    6402     return _result
#    6403   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
