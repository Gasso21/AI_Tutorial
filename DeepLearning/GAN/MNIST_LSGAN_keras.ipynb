# %% [markdown]
# # MNIST

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Input
from tensorflow.keras.optimizers import RMSprop
from keras.models import Model
from keras.datasets import mnist
from keras import backend as K
from keras.models import load_model

import numpy as np
import argparse
import matplotlib.pyplot as plt

from lib import gan

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
def build_and_train_models():
    (x_train, _), (_, _) = mnist.load_data()
    
    # Reshape & Normalize
    image_size = x_train.shape[1]
    x_train = np.reshape(x_train, [-1, image_size, image_size, 1])
    x_train = x_train.astype('float32')/255
    
    model_name = 'lsgan_mnist'
    
    # Network Params
    latent_size = 100 # z-vector dimension
    batch_size = 64
    train_steps = 40000
    lr = 2e-4
    decay = 6e-8
    input_shape = (image_size, image_size, 1)

    # In Keras 2.11.0, 'decay' argument changed to 'weight_decay'
    # Discriminator model
    inputs = keras.Input(shape=input_shape, name='discriminator_input')
    discriminator = gan.discriminator(inputs, activation=None)
    # discriminator = build_discriminator(inputs)
    optimizer = RMSprop(learning_rate=lr)
    discriminator.compile(loss='mse',
                          optimizer=optimizer,
                          metrics=['accuracy']
                         )
    discriminator.summary()
    
    # Generator model
    input_shape = (latent_size, )
    inputs = keras.Input(shape=input_shape, name='z_input')
    generator = gan.generator(inputs, image_size)
    generator.summary()
    
    # Adversarial model
    optimizer = RMSprop(learning_rate=lr*0.5, decay=decay*0.5,)
    discriminator.trainable = False
    ## Adversarial = Generator + Discriminator
    adversarial = Model(inputs, discriminator(generator(inputs)), name=model_name)
    adversarial.compile(loss='mse',
                        optimizer=optimizer,
                        metrics=['accuracy']
                       )
    adversarial.summary()
    
    models = (generator, discriminator, adversarial)
    params = (batch_size, latent_size, train_steps, model_name)
    gan.train(models, x_train, params)

# %%
if __name__=='__main__':
    build_and_train_models()
# Out:
# Metal device set to: Apple M2
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  discriminator_input (InputL  [(None, 28, 28, 1)]      0
#  ayer)
#
#  leaky_re_lu (LeakyReLU)     (None, 28, 28, 1)         0
#
#  conv2d (Conv2D)             (None, 14, 14, 32)        832
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 14, 14, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 64)          51264
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 7, 7, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         204928
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 4, 4, 128)         0
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 256)         819456
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 1)                 4097
#
# =================================================================
# Total params: 1,080,577
# Trainable params: 1,080,577
# Non-trainable params: 0
# _________________________________________________________________
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_input (InputLayer)        [(None, 100)]             0
#
#  dense_1 (Dense)             (None, 6272)              633472
#
#  reshape (Reshape)           (None, 7, 7, 128)         0
#
#  batch_normalization (BatchN  (None, 7, 7, 128)        512
# 2023-02-26 14:28:25.360762: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-02-26 14:28:25.361046: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
#  ormalization)
#
#  activation (Activation)     (None, 7, 7, 128)         0
#
#  conv2d_transpose (Conv2DTra  (None, 14, 14, 128)      409728
#  nspose)
#
#  batch_normalization_1 (Batc  (None, 14, 14, 128)      512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 14, 14, 128)       0
#
#  conv2d_transpose_1 (Conv2DT  (None, 28, 28, 64)       204864
#  ranspose)
#
#  batch_normalization_2 (Batc  (None, 28, 28, 64)       256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 28, 28, 64)        0
#
#  conv2d_transpose_2 (Conv2DT  (None, 28, 28, 32)       51232
#  ranspose)
#
#  batch_normalization_3 (Batc  (None, 28, 28, 32)       128
#  hNormalization)
#
#  activation_3 (Activation)   (None, 28, 28, 32)        0
#
#  conv2d_transpose_3 (Conv2DT  (None, 28, 28, 1)        801
#  ranspose)
#
#  activation_4 (Activation)   (None, 28, 28, 1)         0
#
# =================================================================
# Total params: 1,301,505
# Trainable params: 1,300,801
# Non-trainable params: 704
# _________________________________________________________________
# Model: "lsgan_mnist"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_input (InputLayer)        [(None, 100)]             0
#
#  generator (Functional)      (None, 28, 28, 1)         1301505
#
#  discriminator (Functional)  (None, 1)                 1080577
#
# =================================================================
# Total params: 2,382,082
# Trainable params: 1,300,801
# Non-trainable params: 1,081,281
# _________________________________________________________________
# 2023-02-26 14:28:25.660499: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-02-26 14:28:25.728879: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-02-26 14:28:26.007700: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-02-26 14:28:26.704596: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
#
# 118: [discriminator loss: 0.016181, acc: 1.000000] [adversarial loss: 0.012524, acc: 1.000000]
# 119: [discriminator loss: 0.006995, acc: 1.000000] [adversarial loss: 0.037331, acc: 1.000000]
# 120: [discriminator loss: 0.009501, acc: 1.000000] [adversarial loss: 0.008930, acc: 1.000000]
# 121: [discriminator loss: 0.006138, acc: 1.000000] [adversarial loss: 0.038679, acc: 1.000000]
# 122: [discriminator loss: 0.008866, acc: 1.000000] [adversarial loss: 0.007704, acc: 1.000000]
# 123: [discriminator loss: 0.006252, acc: 1.000000] [adversarial loss: 0.037354, acc: 1.000000]
# 124: [discriminator loss: 0.010844, acc: 1.000000] [adversarial loss: 0.021813, acc: 1.000000]
# 125: [discriminator loss: 0.006906, acc: 1.000000] [adversarial loss: 0.039196, acc: 1.000000]
# 126: [discriminator loss: 0.009164, acc: 1.000000] [adversarial loss: 0.010428, acc: 1.000000]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 if __name__=='__main__':
# ----> 2     build_and_train_models()
#
# Cell In[3], line 50, in build_and_train_models()
#      48 models = (generator, discriminator, adversarial)
#      49 params = (batch_size, latent_size, train_steps, model_name)
# ---> 50 gan.train(models, x_train, params)
#
# File ~/Desktop/Git/Artificial-Intelligence/DeepLearning/GAN/lib/gan.py:188, in train(models, x_train, params)
#     186 noise = np.random.uniform(-1.0, 1.0, size=[batch_size, latent_size])
#     187 # generate fake images
# --> 188 fake_images = generator.predict(noise)
#     189 # real + fake images = 1 batch of train data
#     190 x = np.concatenate((real_images, fake_images))
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/keras/engine/training.py:1978, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1976 callbacks.on_predict_begin()
#    1977 batch_outputs = None
# -> 1978 for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1979   with data_handler.catch_stop_iteration():
#    1980     for step in data_handler.steps():
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/keras/engine/data_adapter.py:1191, in DataHandler.enumerate_epochs(self)
#    1189 """Yields `(epoch, tf.data.Iterator)`."""
#    1190 with self._truncate_execution_to_epoch():
# -> 1191   data_iterator = iter(self._dataset)
#    1192   for epoch in range(self._initial_epoch, self._epochs):
#    1193     if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:486, in DatasetV2.__iter__(self)
#     484 if context.executing_eagerly() or ops.inside_function():
#     485   with ops.colocate_with(self._variant_tensor):
# --> 486     return iterator_ops.OwnedIterator(self)
#     487 else:
#     488   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     489                      "iteration in eager mode or within tf.function.")
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/iterator_ops.py:755, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     751   if (components is not None or element_spec is not None):
#     752     raise ValueError(
#     753         "When `dataset` is provided, `element_spec` and `components` must "
#     754         "not be specified.")
# --> 755   self._create_iterator(dataset)
#     757 self._get_next_call_count = 0
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/iterator_ops.py:787, in OwnedIterator._create_iterator(self, dataset)
#     782 else:
#     783   self._iterator_resource, self._deleter = (
#     784       gen_dataset_ops.anonymous_iterator_v2(
#     785           output_types=self._flat_output_types,
#     786           output_shapes=self._flat_output_shapes))
# --> 787   gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     788   # Delete the resource when this object is deleted
#     789   self._resource_deleter = IteratorResourceDeleter(
#     790       handle=self._iterator_resource,
#     791       deleter=self._deleter)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3315, in make_iterator(dataset, iterator, name)
#    3313 if tld.is_eager:
#    3314   try:
# -> 3315     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3316       _ctx, "MakeIterator", name, dataset, iterator)
#    3317     return _result
#    3318   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
