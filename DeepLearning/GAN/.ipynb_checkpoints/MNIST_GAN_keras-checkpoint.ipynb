# %% [markdown]
# # MNIST

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
from keras.layers import Dense, Reshape, BatchNormalization, Activation, Conv2D, Conv2DTranspose, LeakyReLU, Flatten
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
def build_generator(inputs, image_size):
    # Stack: BN-ReLU-Conv2DTranspose
    # inputs: z-vector(noise)
    # image_size: Target size
    # return: Model
    
    image_resize = image_size // 4
    kernel_size = 5
    layer_filters = [128, 64, 32, 1]
    
    x = Dense(image_resize*image_resize*layer_filters[0])(inputs)
    x = Reshape((image_resize, image_resize, layer_filters[0]))(x)
    
    for filters in layer_filters:
        # 1st, 2nd Conv layers: strides = 2
        # 3rd, 4th Conv layers: strides = 1
        if filters > layer_filters[-2]: #128, 64
            strides = 2
        else:
            strides = 1
        # BN-ReLU-Conv2DTranspose
        x = BatchNormalization()(x)
        x = Conv2DTranspose(filters=filters,
                            kernel_size=kernel_size,
                            strides=strides,
                            padding='same'
                           )(x)
        
    x = Activation('sigmoid')(x)
    generator = keras.Model(inputs, x, name='generator')
    return generator

# %%
def build_discriminator(inputs):
    # BN으로는 수렴하지 않음
    # Stack: LeakyReLU-Conv2D
    # inputs: Image
    # return: Model
    
    kernel_size = 5
    layer_filters = [32, 64, 128, 256]
    
    x = inputs
    
    for filters in layer_filters:
        # 1st, 2nd, 3rd Conv layers: strides = 2
        # 4th Conv layers: strides = 1
        if filters == layer_filters[-1]:
            strides = 1
        else:
            strides = 2
        # LeakyReLU-Conv2D
        x = LeakyReLU(alpha=0.2)(x)
        x = Conv2D(filters=filters,
                   kernel_size=kernel_size,
                   strides=strides,
                   padding='same'
                  )(x)
    x = Flatten()(x)
    x = Dense(1)(x)
    x = Activation('sigmoid')(x)
    discriminator = keras.Model(inputs, x, name='discriminator')
    return discriminator

# %%
def build_and_train_models():
    (x_train, _), (_, _) = keras.datasets.mnist.load_data()
    
    # Reshape & Normalize
    image_size = x_train.shape[1]
    x_train = np.reshape(x_train, [-1, image_size, image_size, 1])
    x_train = x_train.astype('float32')/255
    
    model_name = 'dcgan_mnist'
    # Network Params
    latent_size = 100 # z-vector dimension
    batch_size = 64
    train_steps = 40000
    lr = 2e-4
    decay = 6e-8 # decays the lerning rate over time
    input_shape = (image_size, image_size, 1)
    
    # Discriminator model
    inputs = keras.Input(shape=input_shape, name='discriminator_input')
    discriminator = build_discriminator(inputs)
    optimizer = keras.optimizers.RMSprop(learning_rate=lr, decay=decay)
    discriminator.compile(loss='binary_crossentropy',
                         optimizer=optimizer,
                         metrics=['accuracy']
                        )
    discriminator.summary()
    
    # Generator model
    input_shape = (latent_size, )
    inputs = keras.Input(shape=input_shape, name='z_input')
    generator = build_generator(inputs, image_size)
    generator.summary()
    
    # Adversarial model
    optimizer = keras.optimizers.RMSprop(learning_rate=lr*0.5,
                                         decay=decay*0.5,
                                        )
    discriminator.trainable = False
    ## Adversarial = Generator + Discriminator
    adversarial = keras.Model(inputs, discriminator(generator(inputs)), name='adversarial')
    adversarial.compile(loss='binary_crossentropy',
                        optimizer=optimizer,
                        metrics=['accuracy']
                       )
    adversarial.summary()
    
    models = (generator, discriminator, adversarial)
    params = (batch_size, latent_size, train_steps, model_name)
    train(models, x_train, params)

# %%
def train(models, x_train, params):
    # Discriminator와 Adversarial Model을 배치 단위로 번갈아 훈련
    ## Discriminator는 제대로 레이블이 붙은 진짜와 가짜 이미지를 가지고 훈련
    ## Adversarial는 진짜인 척하는 가짜 이미지로 훈련
    
    # GAN Model
    generator, discriminator, adversarial = models
    
    # Network Params
    batch_size, latent_size, train_steps, model_name = params
    
    # Save Generator Images every 500 epochs
    save_interval = 500
    
    # Noise_Input
    noise_input = np.random.uniform(-1.0, 1.0, size=[16, latent_size]) # 16 x 100
    
    train_size = x_train.shape[0]
    for i in range(train_steps): # train_steps: 40,000
        # First - Discriminator Train
        # Real Images
        rand_indexes = np.random.randint(0, train_size, size=batch_size)
        real_images = x_train[rand_indexes]
        
        # Fake Images
        # Make noise by using Uniform Distribution
        noise = np.random.uniform(-1.0, 1.0, size=[batch_size, latent_size])
        fake_images = generator.predict(noise)
        
        # x: Real Images + Fake Images
        x = np.concatenate((real_images, fake_images))
        # y: real_images-1, fake_images-0
        y = np.ones([2*batch_size, 1])
        y[batch_size:, :] = 0.0
        
        loss, acc = discriminator.train_on_batch(x, y)
        log = "%d: [discriminator loss: %f, acc: %f]" %(i, loss, acc)
        
        # Second - Adversarial Train
        noise = np.random.uniform(-1.0, 1.0, size=[batch_size, latent_size])
        y = np.ones([batch_size, 1])
        
        loss, acc = adversarial.train_on_batch(noise, y)
        log = "%s: [adversarial loss: %f, acc: %f]" %(log, loss, acc)
        print(log)
        
        # Show generator images per 500 epochs
        if (i+1) % save_interval == 0: # 500
            if (i+1) == train_steps: # 40,000
                show = True
            else:
                show = False
            
            plot_images(generator,
                        noise_input=noise_input,
                        show=show,
                        step=(i+1),
                        model_name=model_name
                       )
            
        generator.save(model_name + ".h5")

# %%
if __name__=="__main__":
    build_and_train_models()
# Out:
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  discriminator_input (InputL  [(None, 28, 28, 1)]      0
#  ayer)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 28, 28, 1)         0
#
#  conv2d_20 (Conv2D)          (None, 14, 14, 32)        832
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 14, 14, 32)        0
#
#  conv2d_21 (Conv2D)          (None, 7, 7, 64)          51264
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 7, 7, 64)          0
#
#  conv2d_22 (Conv2D)          (None, 4, 4, 128)         204928
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 4, 4, 128)         0
#
#  conv2d_23 (Conv2D)          (None, 4, 4, 256)         819456
#
#  flatten_4 (Flatten)         (None, 4096)              0
#
#  dense_7 (Dense)             (None, 1)                 4097
#
#  activation_6 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 1,080,577
# Trainable params: 1,080,577
# Non-trainable params: 0
# _________________________________________________________________
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_input (InputLayer)        [(None, 100)]             0
#
#  dense_8 (Dense)             (None, 6272)              633472
#
#  reshape_3 (Reshape)         (None, 7, 7, 128)         0
#
#  batch_normalization_8 (Batc  (None, 7, 7, 128)        512
#  hNormalization)
#
#  conv2d_transpose_8 (Conv2DT  (None, 14, 14, 128)      409728
#  ranspose)
#
#  batch_normalization_9 (Batc  (None, 14, 14, 128)      512
#  hNormalization)
#
#  conv2d_transpose_9 (Conv2DT  (None, 28, 28, 64)       204864
#  ranspose)
#
#  batch_normalization_10 (Bat  (None, 28, 28, 64)       256
#  chNormalization)
#
#  conv2d_transpose_10 (Conv2D  (None, 28, 28, 32)       51232
#  Transpose)
#
#  batch_normalization_11 (Bat  (None, 28, 28, 32)       128
#  chNormalization)
#
#  conv2d_transpose_11 (Conv2D  (None, 28, 28, 1)        801
#  Transpose)
#
#  activation_7 (Activation)   (None, 28, 28, 1)         0
#
# =================================================================
# Total params: 1,301,505
# Trainable params: 1,300,801
# Non-trainable params: 704
# _________________________________________________________________
# Model: "adversarial"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_input (InputLayer)        [(None, 100)]             0
#
#  generator (Functional)      (None, 28, 28, 1)         1301505
#
#  discriminator (Functional)  (None, 1)                 1080577
#
# =================================================================
# Total params: 2,382,082
# Trainable params: 1,300,801
# Non-trainable params: 1,081,281
# _________________________________________________________________
# 2023-02-18 15:33:44.895763: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-02-18 15:33:45.181205: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-02-18 15:33:46.731168: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 0: [discriminator loss: 0.696057, acc: 0.453125]: [adversarial loss: 0.914314, acc: 0.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1: [discriminator loss: 0.606995, acc: 0.718750]: [adversarial loss: 1.204855, acc: 0.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2: [discriminator loss: 0.485886, acc: 0.945312]: [adversarial loss: 1.657105, acc: 0.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 3: [discriminator loss: 0.334701, acc: 1.000000]: [adversarial loss: 1.314607, acc: 0.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 4: [discriminator loss: 0.210769, acc: 1.000000]: [adversarial loss: 3.981655, acc: 0.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 5: [discriminator loss: 0.208015, acc: 0.953125]: [adversarial loss: 1.161368, acc: 0.312500]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 6: [discriminator loss: 0.120058, acc: 1.000000]: [adversarial loss: 3.948273, acc: 0.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 7: [discriminator loss: 0.085129, acc: 0.992188]: [adversarial loss: 2.903707, acc: 0.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 8: [discriminator loss: 0.051032, acc: 1.000000]: [adversarial loss: 2.156044, acc: 0.156250]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 9: [discriminator loss: 0.032837, acc: 1.000000]: [adversarial loss: 2.170028, acc: 0.203125]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 10: [discriminator loss: 0.022426, acc: 1.000000]: [adversarial loss: 2.669158, acc: 0.234375]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 11: [discriminator loss: 0.017038, acc: 1.000000]: [adversarial loss: 2.867652, acc: 0.203125]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 12: [discriminator loss: 0.013724, acc: 1.000000]: [adversarial loss: 2.449024, acc: 0.265625]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 13: [discriminator loss: 0.013316, acc: 1.000000]: [adversarial loss: 1.743327, acc: 0.343750]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 14: [discriminator loss: 0.010302, acc: 1.000000]: [adversarial loss: 1.764322, acc: 0.375000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 15: [discriminator loss: 0.014033, acc: 1.000000]: [adversarial loss: 1.930082, acc: 0.390625]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 16: [discriminator loss: 0.009552, acc: 1.000000]: [adversarial loss: 1.625266, acc: 0.484375]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 17: [discriminator loss: 0.008037, acc: 1.000000]: [adversarial loss: 1.722291, acc: 0.484375]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 18: [discriminator loss: 0.006640, acc: 1.000000]: [adversarial loss: 1.352545, acc: 0.484375]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 19: [discriminator loss: 0.005695, acc: 1.000000]: [adversarial loss: 0.573196, acc: 0.765625]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 20: [discriminator loss: 0.005565, acc: 1.000000]: [adversarial loss: 0.617222, acc: 0.718750]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 21: [discriminator loss: 0.003839, acc: 1.000000]: [adversarial loss: 1.016875, acc: 0.546875]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 22: [discriminator loss: 0.004855, acc: 1.000000]: [adversarial loss: 0.536427, acc: 0.796875]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 23: [discriminator loss: 0.003910, acc: 1.000000]: [adversarial loss: 0.315851, acc: 0.859375]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 24: [discriminator loss: 0.002509, acc: 1.000000]: [adversarial loss: 0.444024, acc: 0.796875]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 25: [discriminator loss: 0.003334, acc: 1.000000]: [adversarial loss: 0.274359, acc: 0.875000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 26: [discriminator loss: 0.002380, acc: 1.000000]: [adversarial loss: 0.146912, acc: 0.953125]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 27: [discriminator loss: 0.002237, acc: 1.000000]: [adversarial loss: 0.130836, acc: 0.937500]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 28: [discriminator loss: 0.001922, acc: 1.000000]: [adversarial loss: 0.150713, acc: 0.921875]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 29: [discriminator loss: 0.001885, acc: 1.000000]: [adversarial loss: 0.089018, acc: 0.968750]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 30: [discriminator loss: 0.001839, acc: 1.000000]: [adversarial loss: 0.050871, acc: 0.984375]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 31: [discriminator loss: 0.001796, acc: 1.000000]: [adversarial loss: 0.069826, acc: 0.984375]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 32: [discriminator loss: 0.001239, acc: 1.000000]: [adversarial loss: 0.063600, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 33: [discriminator loss: 0.001177, acc: 1.000000]: [adversarial loss: 0.025945, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 34: [discriminator loss: 0.001163, acc: 1.000000]: [adversarial loss: 0.035091, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 35: [discriminator loss: 0.001023, acc: 1.000000]: [adversarial loss: 0.018047, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 36: [discriminator loss: 0.000707, acc: 1.000000]: [adversarial loss: 0.020495, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 37: [discriminator loss: 0.001519, acc: 1.000000]: [adversarial loss: 0.015761, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 38: [discriminator loss: 0.000733, acc: 1.000000]: [adversarial loss: 0.022766, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 39: [discriminator loss: 0.000725, acc: 1.000000]: [adversarial loss: 0.016845, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 40: [discriminator loss: 0.000451, acc: 1.000000]: [adversarial loss: 0.024447, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 41: [discriminator loss: 0.000648, acc: 1.000000]: [adversarial loss: 0.009873, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 42: [discriminator loss: 0.000481, acc: 1.000000]: [adversarial loss: 0.008468, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 43: [discriminator loss: 0.000458, acc: 1.000000]: [adversarial loss: 0.013114, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 44: [discriminator loss: 0.000637, acc: 1.000000]: [adversarial loss: 0.013196, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 45: [discriminator loss: 0.000565, acc: 1.000000]: [adversarial loss: 0.007891, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 46: [discriminator loss: 0.000363, acc: 1.000000]: [adversarial loss: 0.012550, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 47: [discriminator loss: 0.000453, acc: 1.000000]: [adversarial loss: 0.008652, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 48: [discriminator loss: 0.000424, acc: 1.000000]: [adversarial loss: 0.004702, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 49: [discriminator loss: 0.000431, acc: 1.000000]: [adversarial loss: 0.005503, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 50: [discriminator loss: 0.000316, acc: 1.000000]: [adversarial loss: 0.007496, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 51: [discriminator loss: 0.000220, acc: 1.000000]: [adversarial loss: 0.010949, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 52: [discriminator loss: 0.000301, acc: 1.000000]: [adversarial loss: 0.003394, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 53: [discriminator loss: 0.000394, acc: 1.000000]: [adversarial loss: 0.002638, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 54: [discriminator loss: 0.000187, acc: 1.000000]: [adversarial loss: 0.006966, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 55: [discriminator loss: 0.000141, acc: 1.000000]: [adversarial loss: 0.007950, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 56: [discriminator loss: 0.000136, acc: 1.000000]: [adversarial loss: 0.004557, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 57: [discriminator loss: 0.000216, acc: 1.000000]: [adversarial loss: 0.003147, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 58: [discriminator loss: 0.000162, acc: 1.000000]: [adversarial loss: 0.002814, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 59: [discriminator loss: 0.000136, acc: 1.000000]: [adversarial loss: 0.002959, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 60: [discriminator loss: 0.000179, acc: 1.000000]: [adversarial loss: 0.001804, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 61: [discriminator loss: 0.000108, acc: 1.000000]: [adversarial loss: 0.002779, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 62: [discriminator loss: 0.000107, acc: 1.000000]: [adversarial loss: 0.002980, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 63: [discriminator loss: 0.000103, acc: 1.000000]: [adversarial loss: 0.003035, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 64: [discriminator loss: 0.000090, acc: 1.000000]: [adversarial loss: 0.002822, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 65: [discriminator loss: 0.000230, acc: 1.000000]: [adversarial loss: 0.000748, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 66: [discriminator loss: 0.000240, acc: 1.000000]: [adversarial loss: 0.001235, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 67: [discriminator loss: 0.000094, acc: 1.000000]: [adversarial loss: 0.001905, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 68: [discriminator loss: 0.000065, acc: 1.000000]: [adversarial loss: 0.002267, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 69: [discriminator loss: 0.000043, acc: 1.000000]: [adversarial loss: 0.002896, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 70: [discriminator loss: 0.000050, acc: 1.000000]: [adversarial loss: 0.002585, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 71: [discriminator loss: 0.000034, acc: 1.000000]: [adversarial loss: 0.002582, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 72: [discriminator loss: 0.000049, acc: 1.000000]: [adversarial loss: 0.002284, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 73: [discriminator loss: 0.000038, acc: 1.000000]: [adversarial loss: 0.003916, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 74: [discriminator loss: 0.000057, acc: 1.000000]: [adversarial loss: 0.003494, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 75: [discriminator loss: 0.000041, acc: 1.000000]: [adversarial loss: 0.003261, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 76: [discriminator loss: 0.000040, acc: 1.000000]: [adversarial loss: 0.001816, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 77: [discriminator loss: 0.000034, acc: 1.000000]: [adversarial loss: 0.004409, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 78: [discriminator loss: 0.000029, acc: 1.000000]: [adversarial loss: 0.003102, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 79: [discriminator loss: 0.000031, acc: 1.000000]: [adversarial loss: 0.002476, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 80: [discriminator loss: 0.000049, acc: 1.000000]: [adversarial loss: 0.001449, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 81: [discriminator loss: 0.000041, acc: 1.000000]: [adversarial loss: 0.001744, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 82: [discriminator loss: 0.000046, acc: 1.000000]: [adversarial loss: 0.001622, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 83: [discriminator loss: 0.000035, acc: 1.000000]: [adversarial loss: 0.001016, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 84: [discriminator loss: 0.000019, acc: 1.000000]: [adversarial loss: 0.002525, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 85: [discriminator loss: 0.000028, acc: 1.000000]: [adversarial loss: 0.001053, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 86: [discriminator loss: 0.000022, acc: 1.000000]: [adversarial loss: 0.002674, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 87: [discriminator loss: 0.000020, acc: 1.000000]: [adversarial loss: 0.003703, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 88: [discriminator loss: 0.000017, acc: 1.000000]: [adversarial loss: 0.004240, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 89: [discriminator loss: 0.000022, acc: 1.000000]: [adversarial loss: 0.034608, acc: 0.984375]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 90: [discriminator loss: 0.000105, acc: 1.000000]: [adversarial loss: 2.184036, acc: 0.562500]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 91: [discriminator loss: 0.000260, acc: 1.000000]: [adversarial loss: 0.017575, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 92: [discriminator loss: 0.012585, acc: 1.000000]: [adversarial loss: 15.380908, acc: 0.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 93: [discriminator loss: 0.294890, acc: 0.875000]: [adversarial loss: 0.001113, acc: 1.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 94: [discriminator loss: 0.006505, acc: 1.000000]: [adversarial loss: 0.036604, acc: 0.984375]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
