# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# # League of Legends Diamond Ranked Games(10min)
#
# [reference](https://www.kaggle.com/code/xiyuewang/lol-how-to-win)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
# %config InlineBackEnd.figure_format='retina'

warnings.filterwarnings('ignore')
sns.set_style('darkgrid')

# %%
df = pd.read_csv('./high_diamond_ranked_10min.csv', encoding='utf-8-sig')

# %% [markdown]
# ## Features
#
# - **gameID**: 게임 판의 고유 ID
# - **blueWins**: 블루팀의 승리 여부 (0: 패배, 1: 승리)
# - **xxxWardsPlaced**: xxx팀의 승리 여부 (0: 패배, 1: 승리)
# - **xxxWardsDestroyed**: xxx팀에서 설치한 와드의 수
# - **xxxFirstBlood**: xxx팀의 첫 번째 킬 달성 여부
# - **xxxKills**: xxx팀의 킬 수
# - **xxxDeaths**: xxx팀의 죽음 수
# - **xxxAssists**: xxx팀의 어시스트 수
# - **xxxEliteMonsters**: xxx팀이 죽인 엘리트 몬스터 수
# - **xxxDragons**: xxx팀이 죽인 용의 수
# - **xxxHeralds**: xxx팀이 죽인 전령의 수
# - **xxxTowersDestroyed**: xxx팀이 파괴한 포탑의 수
# - **xxxTotalGold**: xxx팀의 전체 획득 골드
# - **xxxAvgLevel**: xxx팀의 평균 레벨
# - **xxxTotalExperience**: xxx팀의 총 경험치 획득량
# - **xxxTotalMinionsKilled**: xxx팀의 총 미니언 킬 수
# - **xxxTotalJungleMinionsKilled**: xxx팀의 총 정글 미니언 킬 수
# - **xxxGoldDiff**: xxx팀과 다른 팀 간의 골드 획득량 차이
# - **xxxExperienceDiff**: xxx팀과 다른 팀과의 경험치 획득량 차이
# - **xxxCSPerMin**: xxx팀의 분당 CS 스코어
# - **xxxGoldPerMin**: xxx팀의 분당 골드 획득량

# %%
df.isnull().sum()
# Out:
# gameId                          0
# blueWins                        0
# blueWardsPlaced                 0
# blueWardsDestroyed              0
# blueFirstBlood                  0
# blueKills                       0
# blueDeaths                      0
# blueAssists                     0
# blueEliteMonsters               0
# blueDragons                     0
# blueHeralds                     0
# blueTowersDestroyed             0
# blueTotalGold                   0
# blueAvgLevel                    0
# blueTotalExperience             0
# blueTotalMinionsKilled          0
# blueTotalJungleMinionsKilled    0
# blueGoldDiff                    0
# blueExperienceDiff              0
# blueCSPerMin                    0
# blueGoldPerMin                  0
# redWardsPlaced                  0
# redWardsDestroyed               0
# redFirstBlood                   0
# redKills                        0
# redDeaths                       0
# redAssists                      0
# redEliteMonsters                0
# redDragons                      0
# redHeralds                      0
# redTowersDestroyed              0
# redTotalGold                    0
# redAvgLevel                     0
# redTotalExperience              0
# redTotalMinionsKilled           0
# redTotalJungleMinionsKilled     0
# redGoldDiff                     0
# redExperienceDiff               0
# redCSPerMin                     0
# redGoldPerMin                   0
# dtype: int64

# %%
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#        gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0  4519157822         0               28                   2               1
# 1  4523371949         0               12                   1               0
# 2  4521474530         0               15                   0               0
# 3  4524384067         0               43                   1               0
# 4  4436033771         0               75                   4               0
# 5  4475365709         1               18                   0               0
# 6  4493010632         1               18                   3               1
# 7  4496759358         0               16                   2               0
# 8  4443048030         0               16                   3               0
# 9  4509433346         1               13                   1               1
#
#    blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  \
# 0          9           6           11                  0            0
# 1          5           5            5                  0            0
# 2          7          11            4                  1            1
# 3          4           5            5                  1            0
# 4          6           6            6                  0            0
# 5          5           3            6                  1            1
# 6          7           6            7                  1            1
# 7          5          13            3                  0            0
# 8          7           7            8                  0            0
# 9          4           5            5                  1            1
#
#    blueHeralds  blueTowersDestroyed  blueTotalGold  blueAvgLevel  \
# 0            0                    0          17210          6.60
# 1            0                    0          14712          6.60
# 2            0                    0          16113          6.40
# 3            1                    0          15157          7.00
# 4            0                    0          16400          7.00
# 5            0                    0          15899          7.00
# 6            0                    0          16874          6.80
# 7            0                    0          15305          6.40
# 8            0                    0          16401          7.20
# 9            0                    0          15057          6.80
#
#    blueTotalExperience  blueTotalMinionsKilled  blueTotalJungleMinionsKilled  \
# 0                17039                     195                            36
# 1                16265                     174                            43
# 2                16221                     186                            46
# 3                17954                     201                            55
# 4                18543                     210                            57
# 5                18161                     225                            42
# 6                16967                     225                            53
# 7                16138                     209                            48
# 8                18527                     189                            61
# 9                16805                     220                            39
#
#    blueGoldDiff  blueExperienceDiff  blueCSPerMin  blueGoldPerMin  \
# 0           643                  -8         19.50         1721.00
# 1         -2908               -1173         17.40         1471.20
# 2         -1172               -1033         18.60         1611.30
# 3         -1321                  -7         20.10         1515.70
# 4         -1004                 230         21.00         1640.00
# 5           698                 101         22.50         1589.90
# 6          2411                1563         22.50         1687.40
# 7         -2615                -800         20.90         1530.50
# 8         -1979                -771         18.90         1640.10
# 9         -1548               -1574         22.00         1505.70
#
#    redWardsPlaced  redWardsDestroyed  redFirstBlood  redKills  redDeaths  \
# 0              15                  6              0         6          9
# 1              12                  1              1         5          5
# 2              15                  3              1        11          7
# 3              15                  2              1         5          4
# 4              17                  2              1         6          6
# 5              36                  5              1         3          5
# 6              57                  1              0         6          7
# 7              15                  0              1        13          5
# 8              15                  2              1         7          7
# 9              16                  2              0         5          4
#
#    redAssists  redEliteMonsters  redDragons  redHeralds  redTowersDestroyed  \
# 0           8                 0           0           0                   0
# 1           2                 2           1           1                   1
# 2          14                 0           0           0                   0
# 3          10                 0           0           0                   0
# 4           7                 1           1           0                   0
# 5           2                 0           0           0                   0
# 6           9                 0           0           0                   0
# 7          11                 1           1           0                   0
# 8           5                 2           1           1                   0
# 9           4                 0           0           0                   0
#
#    redTotalGold  redAvgLevel  redTotalExperience  redTotalMinionsKilled  \
# 0         16567         6.80               17047                    197
# 1         17620         6.80               17438                    240
# 2         17285         6.80               17254                    203
# 3         16478         7.00               17961                    235
# 4         17404         7.00               18313                    225
# 5         15201         7.00               18060                    221
# 6         14463         6.40               15404                    164
# 7         17920         6.60               16938                    157
# 8         18380         7.20               19298                    240
# 9         16605         6.80               18379                    247
#
#    redTotalJungleMinionsKilled  redGoldDiff  redExperienceDiff  redCSPerMin  \
# 0                           55         -643                  8        19.70
# 1                           52         2908               1173        24.00
# 2                           28         1172               1033        20.30
# 3                           47         1321                  7        23.50
# 4                           67         1004               -230        22.50
# 5                           59         -698               -101        22.10
# 6                           35        -2411              -1563        16.40
# 7                           54         2615                800        15.70
# 8                           53         1979                771        24.00
# 9                           43         1548               1574        24.70
#
#    redGoldPerMin
# 0        1656.70
# 1        1762.00
# 2        1728.50
# 3        1647.80
# 4        1740.40
# 5        1520.10
# 6        1446.30
# 7        1792.00
# 8        1838.00
# 9        1660.50

# %%
pd.options.display.float_format = '{:.2f}'.format
df[[x for x in df.columns if x not in 'gameId']].describe(include='all').T
# Out:
#                                count     mean     std       min      25%  \
# blueWins                     9879.00     0.50    0.50      0.00     0.00
# blueWardsPlaced              9879.00    22.29   18.02      5.00    14.00
# blueWardsDestroyed           9879.00     2.82    2.17      0.00     1.00
# blueFirstBlood               9879.00     0.50    0.50      0.00     0.00
# blueKills                    9879.00     6.18    3.01      0.00     4.00
# blueDeaths                   9879.00     6.14    2.93      0.00     4.00
# blueAssists                  9879.00     6.65    4.06      0.00     4.00
# blueEliteMonsters            9879.00     0.55    0.63      0.00     0.00
# blueDragons                  9879.00     0.36    0.48      0.00     0.00
# blueHeralds                  9879.00     0.19    0.39      0.00     0.00
# blueTowersDestroyed          9879.00     0.05    0.24      0.00     0.00
# blueTotalGold                9879.00 16503.46 1535.45  10730.00 15415.50
# blueAvgLevel                 9879.00     6.92    0.31      4.60     6.80
# blueTotalExperience          9879.00 17928.11 1200.52  10098.00 17168.00
# blueTotalMinionsKilled       9879.00   216.70   21.86     90.00   202.00
# blueTotalJungleMinionsKilled 9879.00    50.51    9.90      0.00    44.00
# blueGoldDiff                 9879.00    14.41 2453.35 -10830.00 -1585.50
# blueExperienceDiff           9879.00   -33.62 1920.37  -9333.00 -1290.50
# blueCSPerMin                 9879.00    21.67    2.19      9.00    20.20
# blueGoldPerMin               9879.00  1650.35  153.54   1073.00  1541.55
# redWardsPlaced               9879.00    22.37   18.46      6.00    14.00
# redWardsDestroyed            9879.00     2.72    2.14      0.00     1.00
# redFirstBlood                9879.00     0.50    0.50      0.00     0.00
# redKills                     9879.00     6.14    2.93      0.00     4.00
# redDeaths                    9879.00     6.18    3.01      0.00     4.00
# redAssists                   9879.00     6.66    4.06      0.00     4.00
# redEliteMonsters             9879.00     0.57    0.63      0.00     0.00
# redDragons                   9879.00     0.41    0.49      0.00     0.00
# redHeralds                   9879.00     0.16    0.37      0.00     0.00
# redTowersDestroyed           9879.00     0.04    0.22      0.00     0.00
# redTotalGold                 9879.00 16489.04 1490.89  11212.00 15427.50
# redAvgLevel                  9879.00     6.93    0.31      4.80     6.80
# redTotalExperience           9879.00 17961.73 1198.58  10465.00 17209.50
# redTotalMinionsKilled        9879.00   217.35   21.91    107.00   203.00
# redTotalJungleMinionsKilled  9879.00    51.31   10.03      4.00    44.00
# redGoldDiff                  9879.00   -14.41 2453.35 -11467.00 -1596.00
# redExperienceDiff            9879.00    33.62 1920.37  -8348.00 -1212.00
# redCSPerMin                  9879.00    21.73    2.19     10.70    20.30
# redGoldPerMin                9879.00  1648.90  149.09   1121.20  1542.75
#
#                                   50%      75%      max
# blueWins                         0.00     1.00     1.00
# blueWardsPlaced                 16.00    20.00   250.00
# blueWardsDestroyed               3.00     4.00    27.00
# blueFirstBlood                   1.00     1.00     1.00
# blueKills                        6.00     8.00    22.00
# blueDeaths                       6.00     8.00    22.00
# blueAssists                      6.00     9.00    29.00
# blueEliteMonsters                0.00     1.00     2.00
# blueDragons                      0.00     1.00     1.00
# blueHeralds                      0.00     0.00     1.00
# blueTowersDestroyed              0.00     0.00     4.00
# blueTotalGold                16398.00 17459.00 23701.00
# blueAvgLevel                     7.00     7.20     8.00
# blueTotalExperience          17951.00 18724.00 22224.00
# blueTotalMinionsKilled         218.00   232.00   283.00
# blueTotalJungleMinionsKilled    50.00    56.00    92.00
# blueGoldDiff                    14.00  1596.00 11467.00
# blueExperienceDiff             -28.00  1212.00  8348.00
# blueCSPerMin                    21.80    23.20    28.30
# blueGoldPerMin                1639.80  1745.90  2370.10
# redWardsPlaced                  16.00    20.00   276.00
# redWardsDestroyed                2.00     4.00    24.00
# redFirstBlood                    0.00     1.00     1.00
# redKills                         6.00     8.00    22.00
# redDeaths                        6.00     8.00    22.00
# redAssists                       6.00     9.00    28.00
# redEliteMonsters                 0.00     1.00     2.00
# redDragons                       0.00     1.00     1.00
# redHeralds                       0.00     0.00     1.00
# redTowersDestroyed               0.00     0.00     2.00
# redTotalGold                 16378.00 17418.50 22732.00
# redAvgLevel                      7.00     7.20     8.20
# redTotalExperience           17974.00 18764.50 22269.00
# redTotalMinionsKilled          218.00   233.00   289.00
# redTotalJungleMinionsKilled     51.00    57.00    92.00
# redGoldDiff                    -14.00  1585.50 10830.00
# redExperienceDiff               28.00  1290.50  9333.00
# redCSPerMin                     21.80    23.30    28.90
# redGoldPerMin                 1637.80  1741.85  2273.20

# %% [markdown]
# ### Drop Some Repeated Data

# %%
cols = ['gameId', #Object Feature
        'redFirstBlood', #blueFirstBlood
        'redKills', #blueDeaths
        'redDeaths', #blueKill
        'redDragons', #blueDragons
        'redHeralds', #blueHeralds
        'redGoldDiff', #blueGoldDiff
        'redExperienceDiff', #blueExperienceDiff
        ]
df_clean = df.copy()
df_clean = df_clean.drop(cols, axis=1)

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,10))
g1 = sns.PairGrid(data=df_clean, 
                 vars=['blueKills', 'blueAssists', 'blueWardsPlaced', 'blueTotalGold'],
                 hue='blueWins',
                 size=3,
                 palette='Set1',
                 #plot_kws=dict(alpha=0.5)
                )
g1.map_diag(plt.hist, alpha =0.6)
#g1.map_offdiag(plt.scatter, alpha=0.7)
g1.map_lower(plt.scatter, alpha=0.3, edgecolor='black')
g1.map_upper(sns.kdeplot, shade=True)
g1.add_legend()
plt.show()

# %%
plt.figure(figsize=(10,10))
g2 = sns.pairplot(data=df_clean,
                  vars=['blueKills', 'blueAssists', 'blueWardsPlaced', 'blueTotalGold'],
                  hue='blueWins',
                  diag_kind='hist',
                  palette='Set1',
                  plot_kws=dict(alpha=0.7, s=30)
                 )
#g2.map_diag(plt.hist)
#g2.map_offdiag(plt.scatter)
g2.add_legend()
plt.show()

# %%
plt.rcParams['figure.dpi']=200
plt.figure(figsize=(10,10))
threshold=0.5
sns.set_style("whitegrid", {"axes.facecolor":".0"}) #background style: whitegrid, alpha:0
df_cluster = df_clean.drop(['blueWins'],axis=1).corr()
mask = df_cluster.where((abs(df_cluster)>=threshold)).isna()
sns.heatmap(df_cluster,
            cmap='RdYlBu',
            annot=True,
            fmt='.1f',
            annot_kws=dict(size=8),
            mask=mask,
            linewidths=0.2,
            linecolor='lightgrey').set_facecolor('white')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()

# %%
# Based on the correlation matrix, let's clean the dataset a little bit more to avoid colinearity.
df_tmp = df_cluster.where((abs(df_cluster)==1) | (abs(df_cluster)<0.5)).dropna()
cols = list(df_tmp.index)
df_clean = df_clean.drop(cols,axis=1)
# Out:
# ['blueWardsPlaced', 'blueWardsDestroyed', 'blueFirstBlood', 'blueTowersDestroyed', 'blueTotalJungleMinionsKilled', 'redWardsPlaced', 'redWardsDestroyed', 'redTowersDestroyed', 'redTotalJungleMinionsKilled']

# %%
corr_list = df_clean[df_clean.columns[1:]].apply(lambda x: x.corr(df_clean['blueWins']))
cols = []
for col in corr_list.index:
    if abs(corr_list[col])>0.3:
        cols.append(col)
print(cols)
# Out:
# ['blueKills', 'blueDeaths', 'blueTotalGold', 'blueAvgLevel', 'blueTotalExperience', 'blueGoldDiff', 'blueExperienceDiff', 'blueGoldPerMin', 'redTotalGold', 'redAvgLevel', 'redTotalExperience', 'redGoldPerMin']
